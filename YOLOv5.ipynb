# %%
import numpy as np
import os
import json
from PIL import Image
import torch
from torch.utils.data import Dataset
import torchvision.transforms as transforms

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Unzip Dataset

# %%
# !unzip -P 2019Deepfashion2** /content/drive/MyDrive/ECE1508\ DL\ Project/validation.zip  -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/validation/image/007349.jpg
#   inflating: /content/validation/image/007310.jpg
#   inflating: /content/validation/image/007286.jpg
#   inflating: /content/validation/image/007274.jpg
#   inflating: /content/validation/image/007218.jpg
#   inflating: /content/validation/image/007216.jpg
#   inflating: /content/validation/image/007204.jpg
#   inflating: /content/validation/image/007133.jpg
#   inflating: /content/validation/image/007081.jpg
#   inflating: /content/validation/image/007045.jpg
#   inflating: /content/validation/image/007044.jpg
#   inflating: /content/validation/image/007017.jpg
#   inflating: /content/validation/image/006960.jpg
#   inflating: /content/validation/image/006868.jpg
#   inflating: /content/validation/image/006831.jpg
#   inflating: /content/validation/image/006773.jpg
#   inflating: /content/validation/image/006744.jpg
#   inflating: /content/validation/image/006720.jpg
#   inflating: /content/validation/image/006711.jpg
#   inflating: /content/validation/image/006696.jpg
#   inflating: /content/validation/image/006591.jpg
#   inflating: /content/validation/image/006587.jpg
#   inflating: /content/validation/image/006563.jpg
#   inflating: /content/validation/image/006523.jpg
#   inflating: /content/validation/image/006476.jpg
#   inflating: /content/validation/image/006455.jpg
#   inflating: /content/validation/image/006413.jpg
#   inflating: /content/validation/image/006387.jpg
#   inflating: /content/validation/image/006372.jpg
#   inflating: /content/validation/image/006351.jpg
#   inflating: /content/validation/image/006344.jpg
#   inflating: /content/validation/image/006312.jpg
#   inflating: /content/validation/image/006290.jpg
#   inflating: /content/validation/image/006250.jpg
#   inflating: /content/validation/image/006221.jpg
#   inflating: /content/validation/image/006218.jpg
#   inflating: /content/validation/image/006195.jpg
#   inflating: /content/validation/image/006178.jpg
#   inflating: /content/validation/image/006167.jpg
#   inflating: /content/validation/image/006078.jpg
#   inflating: /content/validation/image/006000.jpg
#   inflating: /content/validation/image/005965.jpg
#   inflating: /content/validation/image/005946.jpg
#   inflating: /content/validation/image/005882.jpg
#   inflating: /content/validation/image/005861.jpg
#   inflating: /content/validation/image/005854.jpg
#   inflating: /content/validation/image/005846.jpg
#   inflating: /content/validation/image/005756.jpg
#   inflating: /content/validation/image/005727.jpg
#   inflating: /content/validation/image/005658.jpg
#   inflating: /content/validation/image/005637.jpg
#   inflating: /content/validation/image/005610.jpg
#   inflating: /content/validation/image/005584.jpg
#   inflating: /content/validation/image/005578.jpg
#   inflating: /content/validation/image/005560.jpg
#   inflating: /content/validation/image/005555.jpg
#   inflating: /content/validation/image/005547.jpg
#   inflating: /content/validation/image/005523.jpg
#   inflating: /content/validation/image/005505.jpg
#   inflating: /content/validation/image/005504.jpg
#   inflating: /content/validation/image/005501.jpg
#   inflating: /content/validation/image/005492.jpg
#   inflating: /content/validation/image/005462.jpg
#   inflating: /content/validation/image/005459.jpg
#   inflating: /content/validation/image/005437.jpg
#   inflating: /content/validation/image/005407.jpg
#   inflating: /content/validation/image/005303.jpg
#   inflating: /content/validation/image/005298.jpg
#   inflating: /content/validation/image/005281.jpg
#   inflating: /content/validation/image/005275.jpg
#   inflating: /content/validation/image/005238.jpg
#   inflating: /content/validation/image/005214.jpg
#   inflating: /content/validation/image/005173.jpg
#   inflating: /content/validation/image/005092.jpg
#   inflating: /content/validation/image/004988.jpg
#   inflating: /content/validation/image/004972.jpg
#   inflating: /content/validation/image/004964.jpg
#   inflating: /content/validation/image/004878.jpg
#   inflating: /content/validation/image/004871.jpg
#   inflating: /content/validation/image/004869.jpg
#   inflating: /content/validation/image/004857.jpg
#   inflating: /content/validation/image/004854.jpg
#   inflating: /content/validation/image/004822.jpg
#   inflating: /content/validation/image/004787.jpg
#   inflating: /content/validation/image/004785.jpg
#   inflating: /content/validation/image/004783.jpg
#   inflating: /content/validation/image/004777.jpg
#   inflating: /content/validation/image/004765.jpg
#   inflating: /content/validation/image/004748.jpg
#   inflating: /content/validation/image/004711.jpg
#   inflating: /content/validation/image/004693.jpg
#   inflating: /content/validation/image/004692.jpg
#   inflating: /content/validation/image/004683.jpg
#   inflating: /content/validation/image/004679.jpg
#   inflating: /content/validation/image/004524.jpg
#   inflating: /content/validation/image/004512.jpg
#   inflating: /content/validation/image/004490.jpg
#   inflating: /content/validation/image/004440.jpg
#   inflating: /content/validation/image/004439.jpg
#   inflating: /content/validation/image/004429.jpg
#   inflating: /content/validation/image/004420.jpg
#   inflating: /content/validation/image/004397.jpg
#   inflating: /content/validation/image/004376.jpg
#   inflating: /content/validation/image/004362.jpg
#   inflating: /content/validation/image/004359.jpg
#   inflating: /content/validation/image/004293.jpg
#   inflating: /content/validation/image/004252.jpg
#   inflating: /content/validation/image/004247.jpg
#   inflating: /content/validation/image/004234.jpg
#   inflating: /content/validation/image/004169.jpg
#   inflating: /content/validation/image/004163.jpg
#   inflating: /content/validation/image/011954.jpg
#   inflating: /content/validation/image/011915.jpg
#   inflating: /content/validation/image/011904.jpg
#   inflating: /content/validation/image/011837.jpg
#   inflating: /content/validation/image/011833.jpg
#   inflating: /content/validation/image/011798.jpg
#   inflating: /content/validation/image/011787.jpg
#   inflating: /content/validation/image/011761.jpg
#   inflating: /content/validation/image/011733.jpg
#   inflating: /content/validation/image/011673.jpg
#   inflating: /content/validation/image/011600.jpg
#   inflating: /content/validation/image/011580.jpg
#   inflating: /content/validation/image/011536.jpg
#   inflating: /content/validation/image/011526.jpg
#   inflating: /content/validation/image/011477.jpg
#   inflating: /content/validation/image/011443.jpg
#   inflating: /content/validation/image/011435.jpg
#   inflating: /content/validation/image/011405.jpg
#   inflating: /content/validation/image/011396.jpg
#   inflating: /content/validation/image/011390.jpg
#   inflating: /content/validation/image/011389.jpg
#   inflating: /content/validation/image/011344.jpg
#   inflating: /content/validation/image/011341.jpg
#   inflating: /content/validation/image/011334.jpg
#   inflating: /content/validation/image/011264.jpg
#   inflating: /content/validation/image/011223.jpg
#   inflating: /content/validation/image/011189.jpg
#   inflating: /content/validation/image/011113.jpg
#   inflating: /content/validation/image/011028.jpg
#   inflating: /content/validation/image/011015.jpg
#   inflating: /content/validation/image/010978.jpg
#   inflating: /content/validation/image/010976.jpg
#   inflating: /content/validation/image/010953.jpg
#   inflating: /content/validation/image/010897.jpg
#   inflating: /content/validation/image/010893.jpg
#   inflating: /content/validation/image/010887.jpg
#   inflating: /content/validation/image/010876.jpg
#   inflating: /content/validation/image/010853.jpg
#   inflating: /content/validation/image/010818.jpg
#   inflating: /content/validation/image/010793.jpg
#   inflating: /content/validation/image/010734.jpg
#   inflating: /content/validation/image/010671.jpg
#   inflating: /content/validation/image/010656.jpg
#   inflating: /content/validation/image/010626.jpg
#   inflating: /content/validation/image/010590.jpg
#   inflating: /content/validation/image/010528.jpg
#   inflating: /content/validation/image/010524.jpg
#   inflating: /content/validation/image/010499.jpg
#   inflating: /content/validation/image/010439.jpg
#   inflating: /content/validation/image/010428.jpg
#   inflating: /content/validation/image/010399.jpg
#   inflating: /content/validation/image/010386.jpg
#   inflating: /content/validation/image/010373.jpg
#   inflating: /content/validation/image/010367.jpg
#   inflating: /content/validation/image/010310.jpg
#   inflating: /content/validation/image/010284.jpg
#   inflating: /content/validation/image/010280.jpg
#   inflating: /content/validation/image/010278.jpg
#   inflating: /content/validation/image/010263.jpg
#   inflating: /content/validation/image/010232.jpg
#   inflating: /content/validation/image/010219.jpg
#   inflating: /content/validation/image/010187.jpg
#   inflating: /content/validation/image/010132.jpg
#   inflating: /content/validation/image/010118.jpg
#   inflating: /content/validation/image/010027.jpg
#   inflating: /content/validation/image/009982.jpg
#   inflating: /content/validation/image/009927.jpg
#   inflating: /content/validation/image/009896.jpg
#   inflating: /content/validation/image/009873.jpg
#   inflating: /content/validation/image/009867.jpg
#   inflating: /content/validation/image/009866.jpg
#   inflating: /content/validation/image/009836.jpg
#   inflating: /content/validation/image/009828.jpg
#   inflating: /content/validation/image/009817.jpg
#   inflating: /content/validation/image/009795.jpg
#   inflating: /content/validation/image/009752.jpg
#   inflating: /content/validation/image/009745.jpg
#   inflating: /content/validation/image/009613.jpg
#   inflating: /content/validation/image/009579.jpg
#   inflating: /content/validation/image/009553.jpg
#   inflating: /content/validation/image/009550.jpg
#   inflating: /content/validation/image/009530.jpg
#   inflating: /content/validation/image/009427.jpg
#   inflating: /content/validation/image/009420.jpg
#   inflating: /content/validation/image/009414.jpg
#   inflating: /content/validation/image/009398.jpg
#   inflating: /content/validation/image/009392.jpg
#   inflating: /content/validation/image/009340.jpg
#   inflating: /content/validation/image/009332.jpg
#   inflating: /content/validation/image/009229.jpg
#   inflating: /content/validation/image/009221.jpg
#   inflating: /content/validation/image/009174.jpg
#   inflating: /content/validation/image/009168.jpg
#   inflating: /content/validation/image/009119.jpg
#   inflating: /content/validation/image/009117.jpg
#   inflating: /content/validation/image/009107.jpg
#   inflating: /content/validation/image/009101.jpg
#   inflating: /content/validation/image/009065.jpg
#   inflating: /content/validation/image/009049.jpg
#   inflating: /content/validation/image/009028.jpg
#   inflating: /content/validation/image/009008.jpg
#   inflating: /content/validation/image/009004.jpg
#   inflating: /content/validation/image/008979.jpg
#   inflating: /content/validation/image/008894.jpg
#   inflating: /content/validation/image/008859.jpg
#   inflating: /content/validation/image/008820.jpg
#   inflating: /content/validation/image/008813.jpg
#   inflating: /content/validation/image/008802.jpg
#   inflating: /content/validation/image/008791.jpg
#   inflating: /content/validation/image/008703.jpg
#   inflating: /content/validation/image/008682.jpg
#   inflating: /content/validation/image/008639.jpg
#   inflating: /content/validation/image/008608.jpg
#   inflating: /content/validation/image/008560.jpg
#   inflating: /content/validation/image/008506.jpg
#   inflating: /content/validation/image/008496.jpg
#   inflating: /content/validation/image/008263.jpg
#   inflating: /content/validation/image/008233.jpg
#   inflating: /content/validation/image/008214.jpg
#   inflating: /content/validation/image/008205.jpg
#   inflating: /content/validation/image/008195.jpg
#   inflating: /content/validation/image/008191.jpg
#   inflating: /content/validation/image/008188.jpg
#   inflating: /content/validation/image/008139.jpg
#   inflating: /content/validation/image/008131.jpg
#   inflating: /content/validation/image/008102.jpg
#   inflating: /content/validation/image/008091.jpg
#   inflating: /content/validation/image/008053.jpg
#   inflating: /content/validation/image/016371.jpg
#   inflating: /content/validation/image/016370.jpg
#   inflating: /content/validation/image/016327.jpg
#   inflating: /content/validation/image/016139.jpg
#   inflating: /content/validation/image/016097.jpg
#   inflating: /content/validation/image/016021.jpg
#   inflating: /content/validation/image/016005.jpg
#   inflating: /content/validation/image/015989.jpg
#   inflating: /content/validation/image/015966.jpg
#   inflating: /content/validation/image/015949.jpg
#   inflating: /content/validation/image/015891.jpg
#   inflating: /content/validation/image/015869.jpg
#   inflating: /content/validation/image/015841.jpg
#   inflating: /content/validation/image/015835.jpg
#   inflating: /content/validation/image/015724.jpg
#   inflating: /content/validation/image/015675.jpg
#   inflating: /content/validation/image/015654.jpg
#   inflating: /content/validation/image/015621.jpg
#   inflating: /content/validation/image/015601.jpg
#   inflating: /content/validation/image/015579.jpg
#   inflating: /content/validation/image/015523.jpg
#   inflating: /content/validation/image/015507.jpg
#   inflating: /content/validation/image/015502.jpg
#   inflating: /content/validation/image/015479.jpg
#   inflating: /content/validation/image/015478.jpg
#   inflating: /content/validation/image/015469.jpg
#   inflating: /content/validation/image/015426.jpg
#   inflating: /content/validation/image/015353.jpg
#   inflating: /content/validation/image/015316.jpg
#   inflating: /content/validation/image/015221.jpg
#   inflating: /content/validation/image/015167.jpg
#   inflating: /content/validation/image/015087.jpg
#   inflating: /content/validation/image/015068.jpg
#   inflating: /content/validation/image/014970.jpg
#   inflating: /content/validation/image/014951.jpg
#   inflating: /content/validation/image/014919.jpg
#   inflating: /content/validation/image/014882.jpg
#   inflating: /content/validation/image/014879.jpg
#   inflating: /content/validation/image/014871.jpg
#   inflating: /content/validation/image/014847.jpg
#   inflating: /content/validation/image/014836.jpg
#   inflating: /content/validation/image/014758.jpg
#   inflating: /content/validation/image/014750.jpg
#   inflating: /content/validation/image/014717.jpg
#   inflating: /content/validation/image/014713.jpg
#   inflating: /content/validation/image/014667.jpg
#   inflating: /content/validation/image/014638.jpg
#   inflating: /content/validation/image/014562.jpg
#   inflating: /content/validation/image/014559.jpg
#   inflating: /content/validation/image/014487.jpg
#   inflating: /content/validation/image/014430.jpg
#   inflating: /content/validation/image/014383.jpg
#   inflating: /content/validation/image/014373.jpg
#   inflating: /content/validation/image/014333.jpg
#   inflating: /content/validation/image/014293.jpg
#   inflating: /content/validation/image/014287.jpg
#   inflating: /content/validation/image/014265.jpg
#   inflating: /content/validation/image/014238.jpg
#   inflating: /content/validation/image/014185.jpg
#   inflating: /content/validation/image/014093.jpg
#   inflating: /content/validation/image/014011.jpg
#   inflating: /content/validation/image/013946.jpg
#   inflating: /content/validation/image/013941.jpg
#   inflating: /content/validation/image/013917.jpg
#   inflating: /content/validation/image/013871.jpg
#   inflating: /content/validation/image/013866.jpg
#   inflating: /content/validation/image/013845.jpg
#   inflating: /content/validation/image/013831.jpg
#   inflating: /content/validation/image/013827.jpg
#   inflating: /content/validation/image/013700.jpg
#   inflating: /content/validation/image/013673.jpg
#   inflating: /content/validation/image/013660.jpg
#   inflating: /content/validation/image/013636.jpg
#   inflating: /content/validation/image/013629.jpg
#   inflating: /content/validation/image/013594.jpg
#   inflating: /content/validation/image/013588.jpg
#   inflating: /content/validation/image/013562.jpg
#   inflating: /content/validation/image/013547.jpg
#   inflating: /content/validation/image/013499.jpg
#   inflating: /content/validation/image/013498.jpg
#   inflating: /content/validation/image/013459.jpg
#   inflating: /content/validation/image/013419.jpg
#   inflating: /content/validation/image/013409.jpg
#   inflating: /content/validation/image/013382.jpg
#   inflating: /content/validation/image/013380.jpg
#   inflating: /content/validation/image/013378.jpg
#   inflating: /content/validation/image/013365.jpg
#   inflating: /content/validation/image/013356.jpg
#   inflating: /content/validation/image/013340.jpg
#   inflating: /content/validation/image/013252.jpg
#   inflating: /content/validation/image/013216.jpg
#   inflating: /content/validation/image/013186.jpg
#   inflating: /content/validation/image/013183.jpg
#   inflating: /content/validation/image/013180.jpg
#   inflating: /content/validation/image/013132.jpg
#   inflating: /content/validation/image/013126.jpg
#   inflating: /content/validation/image/013098.jpg
#   inflating: /content/validation/image/013095.jpg
#   inflating: /content/validation/image/012947.jpg
#   inflating: /content/validation/image/012932.jpg
#   inflating: /content/validation/image/012875.jpg
#   inflating: /content/validation/image/012870.jpg
#   inflating: /content/validation/image/012853.jpg
#   inflating: /content/validation/image/012818.jpg
#   inflating: /content/validation/image/012761.jpg
#   inflating: /content/validation/image/012695.jpg
#   inflating: /content/validation/image/012692.jpg
#   inflating: /content/validation/image/012646.jpg
#   inflating: /content/validation/image/012576.jpg
#   inflating: /content/validation/image/012533.jpg
#   inflating: /content/validation/image/012530.jpg
#   inflating: /content/validation/image/012519.jpg
#   inflating: /content/validation/image/012500.jpg
#   inflating: /content/validation/image/012498.jpg
#   inflating: /content/validation/image/012474.jpg
#   inflating: /content/validation/image/012357.jpg
#   inflating: /content/validation/image/012332.jpg
#   inflating: /content/validation/image/012300.jpg
#   inflating: /content/validation/image/012280.jpg
#   inflating: /content/validation/image/012259.jpg
#   inflating: /content/validation/image/012245.jpg
#   inflating: /content/validation/image/012202.jpg
#   inflating: /content/validation/image/012163.jpg
#   inflating: /content/validation/image/012128.jpg
#   inflating: /content/validation/image/012119.jpg
#   inflating: /content/validation/image/012039.jpg
#   inflating: /content/validation/image/012024.jpg
#   inflating: /content/validation/image/011976.jpg
#   inflating: /content/validation/image/020348.jpg
#   inflating: /content/validation/image/020343.jpg
#   inflating: /content/validation/image/020318.jpg
#   inflating: /content/validation/image/020297.jpg
#   inflating: /content/validation/image/020273.jpg
#   inflating: /content/validation/image/020237.jpg
#   inflating: /content/validation/image/020204.jpg
#   inflating: /content/validation/image/020149.jpg
#   inflating: /content/validation/image/020144.jpg
#   inflating: /content/validation/image/020122.jpg
#   inflating: /content/validation/image/020116.jpg
#   inflating: /content/validation/image/020032.jpg
#   inflating: /content/validation/image/019985.jpg
#   inflating: /content/validation/image/019981.jpg
#   inflating: /content/validation/image/019932.jpg
#   inflating: /content/validation/image/019884.jpg
#   inflating: /content/validation/image/019827.jpg
#   inflating: /content/validation/image/019806.jpg
#   inflating: /content/validation/image/019805.jpg
#   inflating: /content/validation/image/019790.jpg
#   inflating: /content/validation/image/019772.jpg
#   inflating: /content/validation/image/019736.jpg
#   inflating: /content/validation/image/019649.jpg
#   inflating: /content/validation/image/019631.jpg
#   inflating: /content/validation/image/019628.jpg
#   inflating: /content/validation/image/019624.jpg
#   inflating: /content/validation/image/019606.jpg
#   inflating: /content/validation/image/019570.jpg
#   inflating: /content/validation/image/019559.jpg
#   inflating: /content/validation/image/019534.jpg
#   inflating: /content/validation/image/019503.jpg
#   inflating: /content/validation/image/019488.jpg
#   inflating: /content/validation/image/019486.jpg
#   inflating: /content/validation/image/019435.jpg
#   inflating: /content/validation/image/019409.jpg
#   inflating: /content/validation/image/019367.jpg
#   inflating: /content/validation/image/019322.jpg
#   inflating: /content/validation/image/019319.jpg
#   inflating: /content/validation/image/019248.jpg
#   inflating: /content/validation/image/019211.jpg
#   inflating: /content/validation/image/019201.jpg
#   inflating: /content/validation/image/019181.jpg
#   inflating: /content/validation/image/019155.jpg
#   inflating: /content/validation/image/019130.jpg
#   inflating: /content/validation/image/019115.jpg
#   inflating: /content/validation/image/019083.jpg
#   inflating: /content/validation/image/019079.jpg
#   inflating: /content/validation/image/019075.jpg
#   inflating: /content/validation/image/019056.jpg
#   inflating: /content/validation/image/019052.jpg
#   inflating: /content/validation/image/019027.jpg
#   inflating: /content/validation/image/019006.jpg
#   inflating: /content/validation/image/018982.jpg
#   inflating: /content/validation/image/018930.jpg
#   inflating: /content/validation/image/018927.jpg
#   inflating: /content/validation/image/018912.jpg
#   inflating: /content/validation/image/018899.jpg
#   inflating: /content/validation/image/018855.jpg
#   inflating: /content/validation/image/018827.jpg
#   inflating: /content/validation/image/018815.jpg
#   inflating: /content/validation/image/018807.jpg
#   inflating: /content/validation/image/018782.jpg
#   inflating: /content/validation/image/018752.jpg
#   inflating: /content/validation/image/018684.jpg
#   inflating: /content/validation/image/018616.jpg
#   inflating: /content/validation/image/018598.jpg
#   inflating: /content/validation/image/018575.jpg
#   inflating: /content/validation/image/018541.jpg
#   inflating: /content/validation/image/018530.jpg
#   inflating: /content/validation/image/018511.jpg
#   inflating: /content/validation/image/018419.jpg
#   inflating: /content/validation/image/018417.jpg
#   inflating: /content/validation/image/018402.jpg
#   inflating: /content/validation/image/018395.jpg
#   inflating: /content/validation/image/018384.jpg
#   inflating: /content/validation/image/018344.jpg
#   inflating: /content/validation/image/018340.jpg
#   inflating: /content/validation/image/018241.jpg
#   inflating: /content/validation/image/018239.jpg
#   inflating: /content/validation/image/018206.jpg
#   inflating: /content/validation/image/018188.jpg
#   inflating: /content/validation/image/018152.jpg
#   inflating: /content/validation/image/018138.jpg
#   inflating: /content/validation/image/018126.jpg
#   inflating: /content/validation/image/018112.jpg
#   inflating: /content/validation/image/018067.jpg
#   inflating: /content/validation/image/018065.jpg
#   inflating: /content/validation/image/018042.jpg
#   inflating: /content/validation/image/018033.jpg
#   inflating: /content/validation/image/018029.jpg
#   inflating: /content/validation/image/017988.jpg
#   inflating: /content/validation/image/017894.jpg
#   inflating: /content/validation/image/017831.jpg
#   inflating: /content/validation/image/017801.jpg
#   inflating: /content/validation/image/017793.jpg
#   inflating: /content/validation/image/017765.jpg
#   inflating: /content/validation/image/017757.jpg
#   inflating: /content/validation/image/017729.jpg
#   inflating: /content/validation/image/017726.jpg
#   inflating: /content/validation/image/017696.jpg
#   inflating: /content/validation/image/017512.jpg
#   inflating: /content/validation/image/017503.jpg
#   inflating: /content/validation/image/017429.jpg
#   inflating: /content/validation/image/017231.jpg
#   inflating: /content/validation/image/017202.jpg
#   inflating: /content/validation/image/017201.jpg
#   inflating: /content/validation/image/017162.jpg
#   inflating: /content/validation/image/017157.jpg
#   inflating: /content/validation/image/017135.jpg
#   inflating: /content/validation/image/017088.jpg
#   inflating: /content/validation/image/017082.jpg
#   inflating: /content/validation/image/017080.jpg
#   inflating: /content/validation/image/017076.jpg
#   inflating: /content/validation/image/016980.jpg
#   inflating: /content/validation/image/016848.jpg
#   inflating: /content/validation/image/016793.jpg
#   inflating: /content/validation/image/016783.jpg
#   inflating: /content/validation/image/016777.jpg
#   inflating: /content/validation/image/016759.jpg
#   inflating: /content/validation/image/016687.jpg
#   inflating: /content/validation/image/016671.jpg
#   inflating: /content/validation/image/016642.jpg
#   inflating: /content/validation/image/016625.jpg
#   inflating: /content/validation/image/016589.jpg
#   inflating: /content/validation/image/016558.jpg
#   inflating: /content/validation/image/016536.jpg
#   inflating: /content/validation/image/016478.jpg
#   inflating: /content/validation/image/016396.jpg
#   inflating: /content/validation/image/025346.jpg
#   inflating: /content/validation/image/025300.jpg
#   inflating: /content/validation/image/025242.jpg
#   inflating: /content/validation/image/025197.jpg
#   inflating: /content/validation/image/025180.jpg
#   inflating: /content/validation/image/025152.jpg
#   inflating: /content/validation/image/025039.jpg
#   inflating: /content/validation/image/024988.jpg
#   inflating: /content/validation/image/024986.jpg
#   inflating: /content/validation/image/024975.jpg
#   inflating: /content/validation/image/024972.jpg
#   inflating: /content/validation/image/024967.jpg
#   inflating: /content/validation/image/024906.jpg
#   inflating: /content/validation/image/024629.jpg
#   inflating: /content/validation/image/024618.jpg
#   inflating: /content/validation/image/024603.jpg
#   inflating: /content/validation/image/024601.jpg
#   inflating: /content/validation/image/024593.jpg
#   inflating: /content/validation/image/024586.jpg
#   inflating: /content/validation/image/024511.jpg
#   inflating: /content/validation/image/024491.jpg
#   inflating: /content/validation/image/024436.jpg
#   inflating: /content/validation/image/024408.jpg
#   inflating: /content/validation/image/024322.jpg
#   inflating: /content/validation/image/024309.jpg
#   inflating: /content/validation/image/024266.jpg
#   inflating: /content/validation/image/024213.jpg
#   inflating: /content/validation/image/024208.jpg
#   inflating: /content/validation/image/024181.jpg
#   inflating: /content/validation/image/024177.jpg
#   inflating: /content/validation/image/024148.jpg
#   inflating: /content/validation/image/024146.jpg
#   inflating: /content/validation/image/024079.jpg
#   inflating: /content/validation/image/024052.jpg
#   inflating: /content/validation/image/023946.jpg
#   inflating: /content/validation/image/023868.jpg
#   inflating: /content/validation/image/023856.jpg
#   inflating: /content/validation/image/023850.jpg
#   inflating: /content/validation/image/023845.jpg
#   inflating: /content/validation/image/023834.jpg
#   inflating: /content/validation/image/023831.jpg
#   inflating: /content/validation/image/023817.jpg
#   inflating: /content/validation/image/023779.jpg
#   inflating: /content/validation/image/023685.jpg
#   inflating: /content/validation/image/023643.jpg
#   inflating: /content/validation/image/023617.jpg
#   inflating: /content/validation/image/023591.jpg
#   inflating: /content/validation/image/023540.jpg
#   inflating: /content/validation/image/023513.jpg
#   inflating: /content/validation/image/023471.jpg
#   inflating: /content/validation/image/023416.jpg
#   inflating: /content/validation/image/023366.jpg
#   inflating: /content/validation/image/023219.jpg
#   inflating: /content/validation/image/023160.jpg
#   inflating: /content/validation/image/022984.jpg
#   inflating: /content/validation/image/022966.jpg
#   inflating: /content/validation/image/022961.jpg
#   inflating: /content/validation/image/022959.jpg
#   inflating: /content/validation/image/022912.jpg
#   inflating: /content/validation/image/022900.jpg
#   inflating: /content/validation/image/022874.jpg
#   inflating: /content/validation/image/022824.jpg
#   inflating: /content/validation/image/022816.jpg
#   inflating: /content/validation/image/022808.jpg
#   inflating: /content/validation/image/022804.jpg
#   inflating: /content/validation/image/022786.jpg
#   inflating: /content/validation/image/022741.jpg
#   inflating: /content/validation/image/022722.jpg
#   inflating: /content/validation/image/022654.jpg
#   inflating: /content/validation/image/022639.jpg
#   inflating: /content/validation/image/022571.jpg
#   inflating: /content/validation/image/022538.jpg
#   inflating: /content/validation/image/022415.jpg
#   inflating: /content/validation/image/022396.jpg
#   inflating: /content/validation/image/022368.jpg
#   inflating: /content/validation/image/022358.jpg
#   inflating: /content/validation/image/022330.jpg
#   inflating: /content/validation/image/022265.jpg
#   inflating: /content/validation/image/022229.jpg
#   inflating: /content/validation/image/022215.jpg
#   inflating: /content/validation/image/022119.jpg
#   inflating: /content/validation/image/022105.jpg
#   inflating: /content/validation/image/022069.jpg
#   inflating: /content/validation/image/022046.jpg
#   inflating: /content/validation/image/022008.jpg
#   inflating: /content/validation/image/021983.jpg
#   inflating: /content/validation/image/021962.jpg
#   inflating: /content/validation/image/021937.jpg
#   inflating: /content/validation/image/021930.jpg
#   inflating: /content/validation/image/021928.jpg
#   inflating: /content/validation/image/021908.jpg
#   inflating: /content/validation/image/021905.jpg
#   inflating: /content/validation/image/021869.jpg
#   inflating: /content/validation/image/021828.jpg
#   inflating: /content/validation/image/021821.jpg
#   inflating: /content/validation/image/021753.jpg
#   inflating: /content/validation/image/021744.jpg
#   inflating: /content/validation/image/021743.jpg
#   inflating: /content/validation/image/021721.jpg
#   inflating: /content/validation/image/021716.jpg
#   inflating: /content/validation/image/021708.jpg
#   inflating: /content/validation/image/021518.jpg
#   inflating: /content/validation/image/021444.jpg
#   inflating: /content/validation/image/021431.jpg
#   inflating: /content/validation/image/021345.jpg
#   inflating: /content/validation/image/021329.jpg
#   inflating: /content/validation/image/021319.jpg
#   inflating: /content/validation/image/021243.jpg
#   inflating: /content/validation/image/021231.jpg
#   inflating: /content/validation/image/021227.jpg
#   inflating: /content/validation/image/021181.jpg
#   inflating: /content/validation/image/021150.jpg
#   inflating: /content/validation/image/021138.jpg
#   inflating: /content/validation/image/021100.jpg
#   inflating: /content/validation/image/020943.jpg
#   inflating: /content/validation/image/020939.jpg
#   inflating: /content/validation/image/020856.jpg
#   inflating: /content/validation/image/020854.jpg
#   inflating: /content/validation/image/020845.jpg
#   inflating: /content/validation/image/020818.jpg
#   inflating: /content/validation/image/020709.jpg
#   inflating: /content/validation/image/020669.jpg
#   inflating: /content/validation/image/020643.jpg
#   inflating: /content/validation/image/020605.jpg
#   inflating: /content/validation/image/020511.jpg
#   inflating: /content/validation/image/020497.jpg
#   inflating: /content/validation/image/020421.jpg
#   inflating: /content/validation/image/020359.jpg
#   inflating: /content/validation/image/029371.jpg
#   inflating: /content/validation/image/029365.jpg
#   inflating: /content/validation/image/029307.jpg
#   inflating: /content/validation/image/029276.jpg
#   inflating: /content/validation/image/029253.jpg
#   inflating: /content/validation/image/029185.jpg
#   inflating: /content/validation/image/029168.jpg
#   inflating: /content/validation/image/029153.jpg
#   inflating: /content/validation/image/029138.jpg
#   inflating: /content/validation/image/029104.jpg
#   inflating: /content/validation/image/029092.jpg
#   inflating: /content/validation/image/029058.jpg
#   inflating: /content/validation/image/029036.jpg
#   inflating: /content/validation/image/029034.jpg
#   inflating: /content/validation/image/029030.jpg
#   inflating: /content/validation/image/029012.jpg
#   inflating: /content/validation/image/028933.jpg
#   inflating: /content/validation/image/028911.jpg
#   inflating: /content/validation/image/028847.jpg
#   inflating: /content/validation/image/028813.jpg
#   inflating: /content/validation/image/028757.jpg
#   inflating: /content/validation/image/028733.jpg
#   inflating: /content/validation/image/028715.jpg
#   inflating: /content/validation/image/028499.jpg
#   inflating: /content/validation/image/028447.jpg
#   inflating: /content/validation/image/028424.jpg
#   inflating: /content/validation/image/028406.jpg
#   inflating: /content/validation/image/028292.jpg
#   inflating: /content/validation/image/028213.jpg
#   inflating: /content/validation/image/028211.jpg
#   inflating: /content/validation/image/028192.jpg
#   inflating: /content/validation/image/028161.jpg
#   inflating: /content/validation/image/028132.jpg
#   inflating: /content/validation/image/028094.jpg
#   inflating: /content/validation/image/028090.jpg
#   inflating: /content/validation/image/028088.jpg
#   inflating: /content/validation/image/028072.jpg
#   inflating: /content/validation/image/028068.jpg
#   inflating: /content/validation/image/028065.jpg
#   inflating: /content/validation/image/028031.jpg
#   inflating: /content/validation/image/027990.jpg
#   inflating: /content/validation/image/027953.jpg
#   inflating: /content/validation/image/027909.jpg
#   inflating: /content/validation/image/027874.jpg
#   inflating: /content/validation/image/027861.jpg
#   inflating: /content/validation/image/027841.jpg
#   inflating: /content/validation/image/027833.jpg
#   inflating: /content/validation/image/027814.jpg
#   inflating: /content/validation/image/027783.jpg
#   inflating: /content/validation/image/027780.jpg
#   inflating: /content/validation/image/027763.jpg
#   inflating: /content/validation/image/027707.jpg
#   inflating: /content/validation/image/027660.jpg
#   inflating: /content/validation/image/027658.jpg
#   inflating: /content/validation/image/027640.jpg
#   inflating: /content/validation/image/027630.jpg
#   inflating: /content/validation/image/027620.jpg
#   inflating: /content/validation/image/027526.jpg
#   inflating: /content/validation/image/027523.jpg
#   inflating: /content/validation/image/027508.jpg
#   inflating: /content/validation/image/027494.jpg
#   inflating: /content/validation/image/027457.jpg
#   inflating: /content/validation/image/027456.jpg
#   inflating: /content/validation/image/027444.jpg
#   inflating: /content/validation/image/027370.jpg
#   inflating: /content/validation/image/027357.jpg
#   inflating: /content/validation/image/027351.jpg
#   inflating: /content/validation/image/027330.jpg
#   inflating: /content/validation/image/027317.jpg
#   inflating: /content/validation/image/027311.jpg
#   inflating: /content/validation/image/027284.jpg
#   inflating: /content/validation/image/027279.jpg
#   inflating: /content/validation/image/027265.jpg
#   inflating: /content/validation/image/027248.jpg
#   inflating: /content/validation/image/027236.jpg
#   inflating: /content/validation/image/027213.jpg
#   inflating: /content/validation/image/027182.jpg
#   inflating: /content/validation/image/027177.jpg
#   inflating: /content/validation/image/027012.jpg
#   inflating: /content/validation/image/027006.jpg
#   inflating: /content/validation/image/026951.jpg
#   inflating: /content/validation/image/026950.jpg
#   inflating: /content/validation/image/026904.jpg
#   inflating: /content/validation/image/026892.jpg
#   inflating: /content/validation/image/026889.jpg
#   inflating: /content/validation/image/026879.jpg
#   inflating: /content/validation/image/026864.jpg
#   inflating: /content/validation/image/026829.jpg
#   inflating: /content/validation/image/026765.jpg
#   inflating: /content/validation/image/026721.jpg
#   inflating: /content/validation/image/026702.jpg
#   inflating: /content/validation/image/026649.jpg
#   inflating: /content/validation/image/026618.jpg
#   inflating: /content/validation/image/026590.jpg
#   inflating: /content/validation/image/026586.jpg
#   inflating: /content/validation/image/026565.jpg
#   inflating: /content/validation/image/026486.jpg
#   inflating: /content/validation/image/026484.jpg
#   inflating: /content/validation/image/026456.jpg
#   inflating: /content/validation/image/026295.jpg
#   inflating: /content/validation/image/026240.jpg
#   inflating: /content/validation/image/026239.jpg
#   inflating: /content/validation/image/026208.jpg
#   inflating: /content/validation/image/026194.jpg
#   inflating: /content/validation/image/026156.jpg
#   inflating: /content/validation/image/026142.jpg
#   inflating: /content/validation/image/026138.jpg
#   inflating: /content/validation/image/026003.jpg
#   inflating: /content/validation/image/025991.jpg
#   inflating: /content/validation/image/025978.jpg
#   inflating: /content/validation/image/025937.jpg
#   inflating: /content/validation/image/025922.jpg
#   inflating: /content/validation/image/025903.jpg
#   inflating: /content/validation/image/025826.jpg
#   inflating: /content/validation/image/025814.jpg
#   inflating: /content/validation/image/025782.jpg
#   inflating: /content/validation/image/025734.jpg
#   inflating: /content/validation/image/025700.jpg
#   inflating: /content/validation/image/025672.jpg
#   inflating: /content/validation/image/025597.jpg
#   inflating: /content/validation/image/025572.jpg
#   inflating: /content/validation/image/025544.jpg
#   inflating: /content/validation/image/025505.jpg
#   inflating: /content/validation/image/025475.jpg
#   inflating: /content/validation/image/025472.jpg
#   inflating: /content/validation/image/025410.jpg
#   inflating: /content/validation/image/025377.jpg
#   inflating: /content/validation/image/025350.jpg
#   inflating: /content/validation/image/001042.jpg
#   inflating: /content/validation/image/000975.jpg
#   inflating: /content/validation/image/000970.jpg
#   inflating: /content/validation/image/000925.jpg
#   inflating: /content/validation/image/000907.jpg
#   inflating: /content/validation/image/000871.jpg
#   inflating: /content/validation/image/000796.jpg
#   inflating: /content/validation/image/000786.jpg
#   inflating: /content/validation/image/000773.jpg
#   inflating: /content/validation/image/000728.jpg
#   inflating: /content/validation/image/000694.jpg
#   inflating: /content/validation/image/000661.jpg
#   inflating: /content/validation/image/000655.jpg
#   inflating: /content/validation/image/000634.jpg
#   inflating: /content/validation/image/000633.jpg
#   inflating: /content/validation/image/000609.jpg
#   inflating: /content/validation/image/000520.jpg
#   inflating: /content/validation/image/000471.jpg
#   inflating: /content/validation/image/000444.jpg
#   inflating: /content/validation/image/000390.jpg
#   inflating: /content/validation/image/000367.jpg
#   inflating: /content/validation/image/000341.jpg
#   inflating: /content/validation/image/000320.jpg
#   inflating: /content/validation/image/000301.jpg
#   inflating: /content/validation/image/000204.jpg
#   inflating: /content/validation/image/000195.jpg
#   inflating: /content/validation/image/000132.jpg
#   inflating: /content/validation/image/000104.jpg
#   inflating: /content/validation/image/000100.jpg
#   inflating: /content/validation/image/000076.jpg
#   inflating: /content/validation/image/000052.jpg
#   inflating: /content/validation/image/000014.jpg
#   inflating: /content/validation/image/032146.jpg
#   inflating: /content/validation/image/032143.jpg
#   inflating: /content/validation/image/032131.jpg
#   inflating: /content/validation/image/032100.jpg
#   inflating: /content/validation/image/032095.jpg
#   inflating: /content/validation/image/032083.jpg
#   inflating: /content/validation/image/032021.jpg
#   inflating: /content/validation/image/031985.jpg
#   inflating: /content/validation/image/031982.jpg
#   inflating: /content/validation/image/031958.jpg
#   inflating: /content/validation/image/031935.jpg
#   inflating: /content/validation/image/031928.jpg
#   inflating: /content/validation/image/031870.jpg
#   inflating: /content/validation/image/031832.jpg
#   inflating: /content/validation/image/031772.jpg
#   inflating: /content/validation/image/031520.jpg
#   inflating: /content/validation/image/031507.jpg
#   inflating: /content/validation/image/031473.jpg
#   inflating: /content/validation/image/031470.jpg
#   inflating: /content/validation/image/031423.jpg
#   inflating: /content/validation/image/031366.jpg
#   inflating: /content/validation/image/031360.jpg
#   inflating: /content/validation/image/031354.jpg
#   inflating: /content/validation/image/031347.jpg
#   inflating: /content/validation/image/031340.jpg
#   inflating: /content/validation/image/031339.jpg
#   inflating: /content/validation/image/031281.jpg
#   inflating: /content/validation/image/031245.jpg
#   inflating: /content/validation/image/031224.jpg
#   inflating: /content/validation/image/031176.jpg
#   inflating: /content/validation/image/031026.jpg
#   inflating: /content/validation/image/030954.jpg
#   inflating: /content/validation/image/030948.jpg
#   inflating: /content/validation/image/030928.jpg
#   inflating: /content/validation/image/030907.jpg
#   inflating: /content/validation/image/030897.jpg
#   inflating: /content/validation/image/030873.jpg
#   inflating: /content/validation/image/030827.jpg
#   inflating: /content/validation/image/030817.jpg
#   inflating: /content/validation/image/030803.jpg
#   inflating: /content/validation/image/030789.jpg
#   inflating: /content/validation/image/030768.jpg
#   inflating: /content/validation/image/030764.jpg
#   inflating: /content/validation/image/030723.jpg
#   inflating: /content/validation/image/030700.jpg
#   inflating: /content/validation/image/030677.jpg
#   inflating: /content/validation/image/030675.jpg
#   inflating: /content/validation/image/030607.jpg
#   inflating: /content/validation/image/030599.jpg
#   inflating: /content/validation/image/030521.jpg
#   inflating: /content/validation/image/030506.jpg
#   inflating: /content/validation/image/030479.jpg
#   inflating: /content/validation/image/030471.jpg
#   inflating: /content/validation/image/030469.jpg
#   inflating: /content/validation/image/030447.jpg
#   inflating: /content/validation/image/030439.jpg
#   inflating: /content/validation/image/030430.jpg
#   inflating: /content/validation/image/030407.jpg
#   inflating: /content/validation/image/030391.jpg
#   inflating: /content/validation/image/030373.jpg
#   inflating: /content/validation/image/030356.jpg
#   inflating: /content/validation/image/030353.jpg
#   inflating: /content/validation/image/030338.jpg
#   inflating: /content/validation/image/030293.jpg
#   inflating: /content/validation/image/030170.jpg
#   inflating: /content/validation/image/030164.jpg
#   inflating: /content/validation/image/030156.jpg
#   inflating: /content/validation/image/030143.jpg
#   inflating: /content/validation/image/030132.jpg
#   inflating: /content/validation/image/030127.jpg
#   inflating: /content/validation/image/030108.jpg
#   inflating: /content/validation/image/030087.jpg
#   inflating: /content/validation/image/030072.jpg
#   inflating: /content/validation/image/030054.jpg
#   inflating: /content/validation/image/030015.jpg
#   inflating: /content/validation/image/030003.jpg
#   inflating: /content/validation/image/029974.jpg
#   inflating: /content/validation/image/029961.jpg
#   inflating: /content/validation/image/029925.jpg
#   inflating: /content/validation/image/029919.jpg
#   inflating: /content/validation/image/029906.jpg
#   inflating: /content/validation/image/029894.jpg
#   inflating: /content/validation/image/029888.jpg
#   inflating: /content/validation/image/029808.jpg
#   inflating: /content/validation/image/029801.jpg
#   inflating: /content/validation/image/029721.jpg
#   inflating: /content/validation/image/029714.jpg
#   inflating: /content/validation/image/029712.jpg
#   inflating: /content/validation/image/029707.jpg
#   inflating: /content/validation/image/029668.jpg
#   inflating: /content/validation/image/029588.jpg
#   inflating: /content/validation/image/029531.jpg
#   inflating: /content/validation/image/029510.jpg
#   inflating: /content/validation/image/029454.jpg
#   inflating: /content/validation/image/029442.jpg
#   inflating: /content/validation/image/029439.jpg
#   inflating: /content/validation/image/005458.jpg
#   inflating: /content/validation/image/005440.jpg
#   inflating: /content/validation/image/005416.jpg
#   inflating: /content/validation/image/005341.jpg
#   inflating: /content/validation/image/005267.jpg
#   inflating: /content/validation/image/005231.jpg
#   inflating: /content/validation/image/005201.jpg
#   inflating: /content/validation/image/005170.jpg
#   inflating: /content/validation/image/005107.jpg
#   inflating: /content/validation/image/005100.jpg
#   inflating: /content/validation/image/005090.jpg
#   inflating: /content/validation/image/005046.jpg
#   inflating: /content/validation/image/005038.jpg
#   inflating: /content/validation/image/004938.jpg
#   inflating: /content/validation/image/004892.jpg
#   inflating: /content/validation/image/004891.jpg
#   inflating: /content/validation/image/004852.jpg
#   inflating: /content/validation/image/004812.jpg
#   inflating: /content/validation/image/004809.jpg
#   inflating: /content/validation/image/004775.jpg
#   inflating: /content/validation/image/004754.jpg
#   inflating: /content/validation/image/004752.jpg
#   inflating: /content/validation/image/004744.jpg
#   inflating: /content/validation/image/004642.jpg
#   inflating: /content/validation/image/004635.jpg
#   inflating: /content/validation/image/004584.jpg
#   inflating: /content/validation/image/004533.jpg
#   inflating: /content/validation/image/004509.jpg
#   inflating: /content/validation/image/004471.jpg
#   inflating: /content/validation/image/004437.jpg
#   inflating: /content/validation/image/004347.jpg
#   inflating: /content/validation/image/004342.jpg
#   inflating: /content/validation/image/004339.jpg
#   inflating: /content/validation/image/004253.jpg
#   inflating: /content/validation/image/004226.jpg
#   inflating: /content/validation/image/004168.jpg
#   inflating: /content/validation/image/004166.jpg
#   inflating: /content/validation/image/004141.jpg
#   inflating: /content/validation/image/004136.jpg
#   inflating: /content/validation/image/004130.jpg
#   inflating: /content/validation/image/004114.jpg
#   inflating: /content/validation/image/004078.jpg
#   inflating: /content/validation/image/004064.jpg
# ...
#   inflating: /content/validation/image/024359.jpg
#   inflating: /content/validation/image/024338.jpg
#   inflating: /content/validation/image/024236.jpg
#   inflating: /content/validation/image/024145.jpg
#   inflating: /content/validation/image/024142.jpg
#   inflating: /content/validation/image/024125.jpg
#   inflating: /content/validation/image/024117.jpg
#   inflating: /content/validation/image/024039.jpg
#   inflating: /content/validation/image/024021.jpg
#   inflating: /content/validation/image/024019.jpg
#   inflating: /content/validation/image/024003.jpg
#   inflating: /content/validation/image/023984.jpg
#   inflating: /content/validation/image/023921.jpg
#   inflating: /content/validation/image/023897.jpg
#   inflating: /content/validation/image/023875.jpg
#   inflating: /content/validation/image/023821.jpg
#   inflating: /content/validation/image/023818.jpg
#   inflating: /content/validation/image/023814.jpg
#   inflating: /content/validation/image/023765.jpg
#   inflating: /content/validation/image/023732.jpg
#   inflating: /content/validation/image/023690.jpg
#   inflating: /content/validation/image/023654.jpg
#   inflating: /content/validation/image/023629.jpg
#   inflating: /content/validation/image/023595.jpg
#   inflating: /content/validation/image/023557.jpg
#   inflating: /content/validation/image/023553.jpg
#   inflating: /content/validation/image/032092.jpg
#   inflating: /content/validation/image/032019.jpg
#   inflating: /content/validation/image/032012.jpg
#   inflating: /content/validation/image/031992.jpg
#   inflating: /content/validation/image/031983.jpg
#   inflating: /content/validation/image/031969.jpg
#   inflating: /content/validation/image/031926.jpg
#   inflating: /content/validation/image/031906.jpg
#   inflating: /content/validation/image/031895.jpg
#   inflating: /content/validation/image/031881.jpg
#   inflating: /content/validation/image/031876.jpg
#   inflating: /content/validation/image/031867.jpg
#   inflating: /content/validation/image/031851.jpg
#   inflating: /content/validation/image/031837.jpg
#   inflating: /content/validation/image/031785.jpg
#   inflating: /content/validation/image/031784.jpg
#   inflating: /content/validation/image/031775.jpg
#   inflating: /content/validation/image/031770.jpg
#   inflating: /content/validation/image/031756.jpg
#   inflating: /content/validation/image/031745.jpg
#   inflating: /content/validation/image/031730.jpg
#   inflating: /content/validation/image/031715.jpg
#   inflating: /content/validation/image/031682.jpg
#   inflating: /content/validation/image/031671.jpg
#   inflating: /content/validation/image/031653.jpg
#   inflating: /content/validation/image/031605.jpg
#   inflating: /content/validation/image/031598.jpg
#   inflating: /content/validation/image/031593.jpg
#   inflating: /content/validation/image/031517.jpg
#   inflating: /content/validation/image/031462.jpg
#   inflating: /content/validation/image/031458.jpg
#   inflating: /content/validation/image/031455.jpg
#   inflating: /content/validation/image/031406.jpg
#   inflating: /content/validation/image/031374.jpg
#   inflating: /content/validation/image/031324.jpg
#   inflating: /content/validation/image/031321.jpg
#   inflating: /content/validation/image/031310.jpg
#   inflating: /content/validation/image/031297.jpg
#   inflating: /content/validation/image/031274.jpg
#   inflating: /content/validation/image/031226.jpg
#   inflating: /content/validation/image/031171.jpg
#   inflating: /content/validation/image/031163.jpg
#   inflating: /content/validation/image/031143.jpg
#   inflating: /content/validation/image/031138.jpg
#   inflating: /content/validation/image/031096.jpg
#   inflating: /content/validation/image/030978.jpg
#   inflating: /content/validation/image/030852.jpg
#   inflating: /content/validation/image/030838.jpg
#   inflating: /content/validation/image/030687.jpg
#   inflating: /content/validation/image/030684.jpg
#   inflating: /content/validation/image/030674.jpg
#   inflating: /content/validation/image/030634.jpg
#   inflating: /content/validation/image/030488.jpg
#   inflating: /content/validation/image/030452.jpg
#   inflating: /content/validation/image/030425.jpg
#   inflating: /content/validation/image/030396.jpg
#   inflating: /content/validation/image/030301.jpg
#   inflating: /content/validation/image/030291.jpg
#   inflating: /content/validation/image/030273.jpg
#   inflating: /content/validation/image/030241.jpg
#   inflating: /content/validation/image/030199.jpg
#   inflating: /content/validation/image/030060.jpg
#   inflating: /content/validation/image/029992.jpg
#   inflating: /content/validation/image/029979.jpg
#   inflating: /content/validation/image/029936.jpg
#   inflating: /content/validation/image/029897.jpg
#   inflating: /content/validation/image/029884.jpg
#   inflating: /content/validation/image/029862.jpg
#   inflating: /content/validation/image/029822.jpg
#   inflating: /content/validation/image/029792.jpg
#   inflating: /content/validation/image/029739.jpg
#   inflating: /content/validation/image/029686.jpg
#   inflating: /content/validation/image/029580.jpg
#   inflating: /content/validation/image/029568.jpg
#   inflating: /content/validation/image/029537.jpg
#   inflating: /content/validation/image/029525.jpg
#   inflating: /content/validation/image/029520.jpg
#   inflating: /content/validation/image/029506.jpg
#   inflating: /content/validation/image/029494.jpg
#   inflating: /content/validation/image/029485.jpg
#   inflating: /content/validation/image/029480.jpg
#   inflating: /content/validation/image/029459.jpg
#   inflating: /content/validation/image/029430.jpg
#   inflating: /content/validation/image/029420.jpg
#   inflating: /content/validation/image/029409.jpg
#   inflating: /content/validation/image/029356.jpg
#   inflating: /content/validation/image/029339.jpg
#   inflating: /content/validation/image/029330.jpg
#   inflating: /content/validation/image/029320.jpg
#   inflating: /content/validation/image/029197.jpg
#   inflating: /content/validation/image/029196.jpg
#   inflating: /content/validation/image/029144.jpg
#   inflating: /content/validation/image/029096.jpg
#   inflating: /content/validation/image/029090.jpg
#   inflating: /content/validation/image/028986.jpg
#   inflating: /content/validation/image/028966.jpg
#   inflating: /content/validation/image/028932.jpg
#   inflating: /content/validation/image/028902.jpg
#   inflating: /content/validation/image/028891.jpg
#   inflating: /content/validation/image/028865.jpg
#   inflating: /content/validation/image/028803.jpg
#   inflating: /content/validation/image/028794.jpg
#   inflating: /content/validation/image/028764.jpg
#   inflating: /content/validation/image/028762.jpg
#   inflating: /content/validation/image/028722.jpg
#   inflating: /content/validation/image/028698.jpg
#   inflating: /content/validation/image/028687.jpg
#   inflating: /content/validation/image/028656.jpg
#   inflating: /content/validation/image/028554.jpg
#   inflating: /content/validation/image/028524.jpg
#   inflating: /content/validation/image/028520.jpg
#   inflating: /content/validation/image/028519.jpg
#   inflating: /content/validation/image/028400.jpg
#   inflating: /content/validation/image/028273.jpg
#   inflating: /content/validation/image/028257.jpg
#   inflating: /content/validation/image/028255.jpg
#   inflating: /content/validation/image/028239.jpg
#   inflating: /content/validation/image/028236.jpg
#   inflating: /content/validation/image/028229.jpg
#   inflating: /content/validation/image/028143.jpg
#   inflating: /content/validation/image/028129.jpg
#   inflating: /content/validation/image/028115.jpg
#   inflating: /content/validation/image/028103.jpg
#   inflating: /content/validation/image/028099.jpg
#   inflating: /content/validation/image/028015.jpg
#   inflating: /content/validation/image/027963.jpg
#   inflating: /content/validation/image/027938.jpg
#   inflating: /content/validation/image/027919.jpg
#   inflating: /content/validation/image/025360.jpg
#   inflating: /content/validation/image/025074.jpg
#   inflating: /content/validation/image/024982.jpg
#   inflating: /content/validation/image/024740.jpg
#   inflating: /content/validation/image/024332.jpg
#   inflating: /content/validation/image/024306.jpg
#   inflating: /content/validation/image/024153.jpg
#   inflating: /content/validation/image/024065.jpg
#   inflating: /content/validation/image/023933.jpg
#   inflating: /content/validation/image/023712.jpg
#   inflating: /content/validation/image/023538.jpg
#   inflating: /content/validation/image/023316.jpg
#   inflating: /content/validation/image/023173.jpg
#   inflating: /content/validation/image/023010.jpg
#   inflating: /content/validation/image/022913.jpg
#   inflating: /content/validation/image/022906.jpg
#   inflating: /content/validation/image/022688.jpg
#   inflating: /content/validation/image/022072.jpg
#   inflating: /content/validation/image/021812.jpg
#   inflating: /content/validation/image/021766.jpg
#   inflating: /content/validation/image/021580.jpg
#   inflating: /content/validation/image/021283.jpg
#   inflating: /content/validation/image/021179.jpg
#   inflating: /content/validation/image/021056.jpg
#   inflating: /content/validation/image/020941.jpg
#   inflating: /content/validation/image/020261.jpg
#   inflating: /content/validation/image/020121.jpg
#   inflating: /content/validation/image/019937.jpg
#   inflating: /content/validation/image/019074.jpg
#   inflating: /content/validation/image/019012.jpg
#   inflating: /content/validation/image/018937.jpg
#   inflating: /content/validation/image/018432.jpg
#   inflating: /content/validation/image/017930.jpg
#   inflating: /content/validation/image/017761.jpg
#   inflating: /content/validation/image/017691.jpg
#   inflating: /content/validation/image/017499.jpg
#   inflating: /content/validation/image/017482.jpg
#   inflating: /content/validation/image/017330.jpg
#   inflating: /content/validation/image/017311.jpg
#   inflating: /content/validation/image/017224.jpg
#   inflating: /content/validation/image/017047.jpg
#   inflating: /content/validation/image/016967.jpg
#   inflating: /content/validation/image/016882.jpg
#   inflating: /content/validation/image/016654.jpg
#   inflating: /content/validation/image/016599.jpg
#   inflating: /content/validation/image/016489.jpg
#   inflating: /content/validation/image/015921.jpg
#   inflating: /content/validation/image/015783.jpg
#   inflating: /content/validation/image/015458.jpg
#   inflating: /content/validation/image/014842.jpg
#   inflating: /content/validation/image/014781.jpg
#   inflating: /content/validation/image/014611.jpg
#   inflating: /content/validation/image/014407.jpg
#   inflating: /content/validation/image/014210.jpg
#   inflating: /content/validation/image/013887.jpg
#   inflating: /content/validation/image/013769.jpg
#   inflating: /content/validation/image/013693.jpg
#   inflating: /content/validation/image/012998.jpg
#   inflating: /content/validation/image/012771.jpg
#   inflating: /content/validation/image/012592.jpg
#   inflating: /content/validation/image/012441.jpg
#   inflating: /content/validation/image/012258.jpg
#   inflating: /content/validation/image/012032.jpg
#   inflating: /content/validation/image/011870.jpg
#   inflating: /content/validation/image/011715.jpg
#   inflating: /content/validation/image/011476.jpg
#   inflating: /content/validation/image/011148.jpg
#   inflating: /content/validation/image/011044.jpg
#   inflating: /content/validation/image/010958.jpg
#   inflating: /content/validation/image/010797.jpg
#   inflating: /content/validation/image/010772.jpg
#   inflating: /content/validation/image/010467.jpg
#   inflating: /content/validation/image/010299.jpg
#   inflating: /content/validation/image/009914.jpg
#   inflating: /content/validation/image/009582.jpg
#   inflating: /content/validation/image/009354.jpg
#   inflating: /content/validation/image/008955.jpg
#   inflating: /content/validation/image/008905.jpg
#   inflating: /content/validation/image/008768.jpg
#   inflating: /content/validation/image/008597.jpg
#   inflating: /content/validation/image/008468.jpg
#   inflating: /content/validation/image/008229.jpg
#   inflating: /content/validation/image/008137.jpg
#   inflating: /content/validation/image/007668.jpg
#   inflating: /content/validation/image/007634.jpg
#   inflating: /content/validation/image/007464.jpg
#   inflating: /content/validation/image/007239.jpg
#   inflating: /content/validation/image/007200.jpg
#   inflating: /content/validation/image/007158.jpg
#   inflating: /content/validation/image/007144.jpg
#   inflating: /content/validation/image/006857.jpg
#   inflating: /content/validation/image/006813.jpg
#   inflating: /content/validation/image/006600.jpg
#   inflating: /content/validation/image/006568.jpg
#   inflating: /content/validation/image/006424.jpg
#   inflating: /content/validation/image/006370.jpg
#   inflating: /content/validation/image/006138.jpg
#   inflating: /content/validation/image/006108.jpg
#   inflating: /content/validation/image/005678.jpg
#   inflating: /content/validation/image/005573.jpg
#   inflating: /content/validation/image/005058.jpg
#   inflating: /content/validation/image/004987.jpg
#   inflating: /content/validation/image/004909.jpg
#   inflating: /content/validation/image/004705.jpg
#   inflating: /content/validation/image/004131.jpg
#   inflating: /content/validation/image/003582.jpg
#   inflating: /content/validation/image/003580.jpg
#   inflating: /content/validation/image/003503.jpg
#   inflating: /content/validation/image/003434.jpg
#   inflating: /content/validation/image/003157.jpg
#   inflating: /content/validation/image/002710.jpg
#   inflating: /content/validation/image/002073.jpg
#   inflating: /content/validation/image/002050.jpg
#   inflating: /content/validation/image/001991.jpg
#   inflating: /content/validation/image/001910.jpg
#   inflating: /content/validation/image/001614.jpg
#   inflating: /content/validation/image/001550.jpg
#   inflating: /content/validation/image/001445.jpg
#   inflating: /content/validation/image/001434.jpg
#   inflating: /content/validation/image/001384.jpg
#   inflating: /content/validation/image/001348.jpg
#   inflating: /content/validation/image/001260.jpg
#   inflating: /content/validation/image/001229.jpg
#   inflating: /content/validation/image/001107.jpg
#   inflating: /content/validation/image/000481.jpg
#   inflating: /content/validation/image/000114.jpg
#   inflating: /content/validation/image/000109.jpg
#   inflating: /content/validation/image/000038.jpg
#   inflating: /content/validation/image/031666.jpg
#   inflating: /content/validation/image/031551.jpg
#   inflating: /content/validation/image/031414.jpg
#   inflating: /content/validation/image/030969.jpg
#   inflating: /content/validation/image/030853.jpg
#   inflating: /content/validation/image/030800.jpg
#   inflating: /content/validation/image/030584.jpg
#   inflating: /content/validation/image/030213.jpg
#   inflating: /content/validation/image/029416.jpg
#   inflating: /content/validation/image/029384.jpg
#   inflating: /content/validation/image/029254.jpg
#   inflating: /content/validation/image/028293.jpg
#   inflating: /content/validation/image/027927.jpg
#   inflating: /content/validation/image/027687.jpg
#   inflating: /content/validation/image/027613.jpg
#   inflating: /content/validation/image/027528.jpg
#   inflating: /content/validation/image/027511.jpg
#   inflating: /content/validation/image/027489.jpg
#   inflating: /content/validation/image/027258.jpg
#   inflating: /content/validation/image/026994.jpg
#   inflating: /content/validation/image/026423.jpg
#   inflating: /content/validation/image/026213.jpg
#   inflating: /content/validation/image/026205.jpg
#   inflating: /content/validation/image/025844.jpg
#   inflating: /content/validation/image/025818.jpg

# %%
# !ls /content/validation/image -1 -R | wc -l
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# 32154

# %% [markdown]
# ## Dataframe of Dataset

# %%
with open('/content/validation/annos/000002.json') as f:
  test_anno = json.load(f)

# %%
test_anno.keys()
# Out:
# dict_keys(['item2', 'source', 'pair_id', 'item1'])

# %%
test_anno['item1'].keys()
# Out:
# dict_keys(['segmentation', 'scale', 'viewpoint', 'zoom_in', 'landmarks', 'style', 'bounding_box', 'category_id', 'occlusion', 'category_name'])

# %%
import pandas as pd
from multiprocessing import Pool
from tqdm import tqdm

root_dir = '/content/validation'
image_dir = os.path.join(root_dir, 'image')
annotation_dir = os.path.join(root_dir, 'annos')
image_files = os.listdir(image_dir)

def load_data(img_file):
    """
    Loads data and store into a dataframe
    """
    img_name = os.path.join(image_dir, img_file)
    annotation_name = os.path.join(annotation_dir, os.path.splitext(img_file)[0] + '.json')

    # Load annotation
    with open(annotation_name) as f:
        annotation = json.load(f)

    # Extract specific keys and their nested values
    item1 = annotation.get('item1', {})
    item2 = annotation.get('item2', {})

    item1_category_name = item1.get('category_name', None)
    item1_scale = item1.get('scale', None)
    item1_bounding_box = item1.get('bounding_box', None)
    item1_category_id = item1.get('category_id', None)

    item2_category_name = item2.get('category_name', None)
    item2_scale = item2.get('scale', None)
    item2_bounding_box = item2.get('bounding_box', None)
    item2_category_id = item2.get('category_id', None)

    return {
            'image_file': img_file,
            'item1_category_name': item1_category_name,
            'item1_scale': item1_scale,
            'item1_bounding_box': item1_bounding_box,
            'item1_category_id': item1_category_id,
            'item2_category_name': item2_category_name,
            'item2_scale': item2_scale,
            'item2_bounding_box': item2_bounding_box,
            'item2_category_id': item2_category_id}

# Create a pool of workers
num_workers = os.cpu_count()  # Use the number of CPU cores
with Pool(num_workers) as pool:
    data = list(tqdm(pool.imap(load_data, image_files), total=len(image_files)))

# Convert list of dictionaries to DataFrame
df = pd.DataFrame(data)

# Example:
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# 100%|██████████| 32153/32153 [00:17<00:00, 1809.21it/s]
#    image_file item1_category_name  item1_scale  item1_bounding_box  \
# 0  005481.jpg  short sleeve dress            3    [0, 0, 620, 467]
# 1  019259.jpg     long sleeve top            2   [94, 0, 509, 188]
# 2  000376.jpg               sling            3   [92, 1, 466, 444]
# 3  010603.jpg          vest dress            3    [2, 5, 290, 463]
# 4  003474.jpg               skirt            3  [0, 104, 467, 564]
#
#    item1_category_id item2_category_name  item2_scale    item2_bounding_box  \
# 0                 10                None          NaN                  None
# 1                  2               skirt          3.0   [81, 112, 621, 604]
# 2                  6            trousers          2.0  [113, 377, 402, 623]
# 3                 12                None          NaN                  None
# 4                  9                None          NaN                  None
#
#    item2_category_id
# 0                NaN
# 1                9.0
# 2                8.0
# 3                NaN
# 4                NaN

# %%
df['item1_category_name'].value_counts(normalize=True)
# Out:
# short sleeve top        0.298666
# long sleeve top         0.137281
# short sleeve dress      0.094113
# vest dress              0.093117
# trousers                0.086835
# skirt                   0.067054
# vest                    0.054521
# long sleeve outwear     0.052686
# long sleeve dress       0.043635
# shorts                  0.037322
# sling dress             0.022580
# sling                   0.008864
# short sleeve outwear    0.003328
# Name: item1_category_name, dtype: float64

# %%
df['item2_category_name'].value_counts(normalize=True)
# Out:
# trousers                0.325697
# skirt                   0.220761
# shorts                  0.149314
# short sleeve top        0.145411
# long sleeve top         0.074323
# sling dress             0.021265
# vest                    0.018029
# vest dress              0.017823
# long sleeve outwear     0.015409
# short sleeve dress      0.004623
# long sleeve dress       0.003801
# short sleeve outwear    0.001798
# sling                   0.001746
# Name: item2_category_name, dtype: float64

# %%
df[df['item2_category_name'].isna()].shape
# Out:
# (12684, 9)

# %% [markdown]
# ## Create dictionary of classes (type of clothing present in dataset)

# %%
item_categories = {}
unique_categories =  df['item1_category_name'].unique()

for i in range(len(unique_categories)):
  item_categories[unique_categories[i]] = i

# %% [markdown]
# ## Convert bbox into YOLO format

# %%
from sklearn import preprocessing

def create_YOLO_bbox_str(bbox, img_size):
  """
  Convert bbox (x1, y1, x2, y2) to YOLO format (x_center, y_center, w, h) and normalize it according to the image size
  """
  x_center = (bbox[0] + bbox[2])/(2*img_size)
  y_center = (bbox[1] + bbox[3])/(2*img_size)
  w = (bbox[2] - bbox[0])/img_size
  h = (bbox[3] - bbox[1])/img_size

  bbox_str = str(round(x_center, 6)) + " " + str(round(y_center, 6)) + " " + str(round(w, 6)) + " " + str(round(h, 6))

  return bbox_str

# %% [markdown]
# ## Create custom dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.image_dir = os.path.join(root_dir, 'image')
        self.annotation_dir = os.path.join(root_dir, 'annos')
        self.image_files = os.listdir(self.image_dir)
        self.image_size = 352 # Change default YOLO input from 640 to speed up training process

    def __len__(self):
        return len(self.image_files)

    def __getitemcategories__(self, idx):
        annotation_name = os.path.join(self.annotation_dir, os.path.splitext(self.image_files[idx])[0] + '.json')

        with open(annotation_name) as f:
            annotation = json.load(f)

        # Extract items and their category names
        item1 = annotation.get('item1', {})
        item2 = annotation.get('item2', {})
        item1_category_name = item1.get('category_name', None)
        item2_category_name = item2.get('category_name', None)

        return [item1_category_name, item2_category_name]

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.image_files[idx])
        annotation_name = os.path.join(self.annotation_dir, os.path.splitext(self.image_files[idx])[0] + '.json')

        # Create image
        image = Image.open(img_name).convert('RGB')

        # Resize image
        image_width, image_height = image.size
        image = image.resize((self.image_size, self.image_size))

        with open(annotation_name) as f:
            annotation = json.load(f)

        # Extract specific keys and their nested values
        item1 = annotation.get('item1', {})
        item2 = annotation.get('item2', {})

        item1_category_name = item1.get('category_name', None)
        item1_bounding_box = item1.get('bounding_box', None)
        item1_bounding_box[0] = item1_bounding_box[0] / image_width * self.image_size
        item1_bounding_box[1] = item1_bounding_box[1] / image_height * self.image_size
        item1_bounding_box[2] = item1_bounding_box[2] / image_width * self.image_size
        item1_bounding_box[3] = item1_bounding_box[3] / image_height * self.image_size

        item2_category_name = item2.get('category_name', None)
        item2_bounding_box = item2.get('bounding_box', None)
        if item2_bounding_box is not None: # In some cases there is not a second item in the image
          item2_bounding_box[0] = item2_bounding_box[0] / image_width * self.image_size
          item2_bounding_box[1] = item2_bounding_box[1] / image_height * self.image_size
          item2_bounding_box[2] = item2_bounding_box[2] / image_width * self.image_size
          item2_bounding_box[3] = item2_bounding_box[3] / image_height * self.image_size

        # Create label for image with integer representing class and bbox
        f = open(f"im{idx}.txt", "w")
        f.write(str(item_categories[item1_category_name]) + " " + create_YOLO_bbox_str(item1_bounding_box, self.image_size) + "\n")

        if item2_category_name is not None:
          f.write(str(item_categories[item2_category_name]) + " " + create_YOLO_bbox_str(item2_bounding_box, self.image_size))

        f.close()

        return image

# Create dataset
dataset = CustomDataset('/content/validation')

# %% [markdown]
# ## Dataset Split

# %%
import random
import shutil

def data_splitter(dataset, new_dataset_size, train_size, val_size):
  """
  Creates directories to store images and labels for test, train and validation
  Splits data randomly into test, train and validation according to the specified size
  Tries to balance dataset manually, while keeping YOLO format intact (why train_test_split was not used)
  """

  # Paths of directories (directory tree specific to YOLO format)
  train_images_dir = '/content/drive/My Drive/YOLOv5_work/images/train'
  train_labels_dir = '/content/drive/My Drive/YOLOv5_work/labels/train'
  val_images_dir = '/content/drive/My Drive/YOLOv5_work/images/val'
  val_labels_dir = '/content/drive/My Drive/YOLOv5_work/labels/val'
  test_images_dir = '/content/drive/My Drive/YOLOv5_work/images/test'
  test_labels_dir = '/content/drive/My Drive/YOLOv5_work/labels/test'

  # Delete folders if the path exists (to overwrite current dataset)
  if os.path.exists(train_images_dir):
    shutil.rmtree(train_images_dir)
  if os.path.exists(train_labels_dir):
    shutil.rmtree(train_labels_dir)
  if os.path.exists(val_images_dir):
    shutil.rmtree(val_images_dir)
  if os.path.exists(val_labels_dir):
    shutil.rmtree(val_labels_dir)
  if os.path.exists(test_images_dir):
    shutil.rmtree(test_images_dir)
  if os.path.exists(test_labels_dir):
    shutil.rmtree(test_labels_dir)

  # Create directories
  os.makedirs(train_images_dir, exist_ok=True)
  os.makedirs(train_labels_dir, exist_ok=True)
  os.makedirs(val_images_dir, exist_ok=True)
  os.makedirs(val_labels_dir, exist_ok=True)
  os.makedirs(test_images_dir, exist_ok=True)
  os.makedirs(test_labels_dir, exist_ok=True)

  # Set of randomly selected indicies for 3x the desired dataset size
  numbers = random.sample(range(0, dataset.__len__()), new_dataset_size*3)
  new_set = numbers[:]

  # Counters for items that the model was overfit with (in previous iterations)
  skirt_count = 0
  dress_count = 0
  short_sleeve_top_count = 0
  short_sleeve_out_count = 0
  long_sleeve_top_count = 0

  # Go through the set of indicies and remove them if they go over the threshold for total number of instances (relative to desired dataset size)
  for i in numbers:
    categories = dataset.__getitemcategories__(i)
    remove_item = False

    for j in categories:
        if j == 'skirt' and skirt_count > 0.25 * new_dataset_size:
            remove_item = True
        elif j in ['long sleeve dress', 'short sleeve dress', 'vest dress', 'sling dress'] and dress_count > 0.35 * new_dataset_size:
            remove_item = True
        elif j == 'short sleeve top' and short_sleeve_top_count > 0.2 * new_dataset_size:
            remove_item = True
        elif j == 'short sleeve outwear' and short_sleeve_out_count > 0.005 * new_dataset_size:
            remove_item = True
        elif j == 'long sleeve top' and long_sleeve_top_count > 0.2 * new_dataset_size:
            remove_item = True

        if j == 'skirt':
            skirt_count += 1
        elif j in ['long sleeve dress', 'short sleeve dress', 'vest dress', 'sling dress']:
            dress_count += 1
        elif j == 'short sleeve top':
            short_sleeve_top_count+=1
        elif j == 'short sleeve outwear':
            short_sleeve_out_count += 1
        elif j == 'long sleeve top':
            long_sleeve_top_count += 1

    if remove_item:
        new_set.remove(i)

  # Update dataset to be using the more balanced dataset
  numbers = random.sample(new_set, new_dataset_size)
  train_indicies = random.sample(numbers, int(train_size*new_dataset_size)) # Randomly select training dataset (indicies)

  # Process training dataset (images + labels)
  for i in range(dataset.__len__()):
    if i in train_indicies:
      print(f"Processing train image {i}")

      image = dataset.__getitem__(i)
      image.save(train_images_dir + "/" +  f"im{i}.jpg")
      label_file = f"im{i}.txt"
      label_file_path = os.path.join(train_labels_dir, label_file)

      if os.path.exists(label_file_path):
          os.unlink(label_file_path)

      shutil.copy2(label_file, train_labels_dir)

      numbers.remove(i) # Remove current index

  # Randomly select validation dataset (indicies)
  val_indicies = random.sample(numbers, int(val_size*new_dataset_size))

  # Process validation and testing datasets (images + labels)
  for i in numbers:
    if i in val_indicies:
      print(f"Processing val image {i}")

      image = dataset.__getitem__(i)
      image.save(val_images_dir + "/" +  f"im{i}.jpg")
      label_file = f"im{i}.txt"
      label_file_path = os.path.join(val_labels_dir, label_file)

      if os.path.exists(label_file_path):
          os.unlink(label_file_path)
      shutil.copy2(label_file, val_labels_dir)
    else:
      print(f"Processing test image {i}")

      image = dataset.__getitem__(i)
      image.save(test_images_dir + "/" +  f"im{i}.jpg")
      label_file = f"im{i}.txt"
      label_file_path = os.path.join(test_labels_dir, label_file)

      if os.path.exists(label_file_path):
          os.unlink(label_file_path)
      shutil.copy2(label_file, test_labels_dir)

# %%
# Create dataset for training, testing and validation (images + labels stored in Drive)
data_splitter(dataset, 6000, 0.7, 0.1)

# %%
# Download YOLOv5 + requirements
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies

# %% [markdown]
# ## Training + Validation
# Epochs = 10, Batch size = 20 <br>
# Custom config.yaml file specifies file locations of training and validation data and overwrites the number of output classes to 13 (from 80)
#
# Following general steps taken here: https://www.kaggle.com/code/mostafaibrahim17/yolov5/notebook

# %%
# %cd /content/drive/My Drive
# %cd yolov5

# !python train.py --img 352 --batch 20 --epochs 10 --data /content/drive/My\ Drive/YOLOv5_yaml/yolo_config.yaml --weights yolov5s.pt
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/yolov5
# 2024-04-05 18:44:07.827928: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 18:44:07.828042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 18:44:07.831555: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=/content/drive/My Drive/YOLOv5_yaml/yolo_config.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=20, imgsz=352, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/content/drive/My': No such file or directory
# YOLOv5 🚀 2024-4-2 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=13
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     48546  models.yolo.Detect                      [13, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7054690 parameters, 7054690 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.00046875), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/My Drive/YOLOv5_work/labels/train... 4200 images, 0 backgrounds, 0 corrupt: 100% 4200/4200 [02:51<00:00, 24.46it/s]
# train: New cache created: /content/drive/My Drive/YOLOv5_work/labels/train.cache
# val: Scanning /content/drive/My Drive/YOLOv5_work/labels/val... 600 images, 0 backgrounds, 0 corrupt: 100% 600/600 [00:12<00:00, 49.10it/s]
# val: New cache created: /content/drive/My Drive/YOLOv5_work/labels/val.cache
#
# AutoAnchor: 4.40 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp17/labels.jpg...
# Image sizes 352 train, 352 val
# Using 2 dataloader workers
# Logging results to runs/train/exp17
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9         0G    0.07914    0.02825    0.06732         70        352:  61% 128/210 [22:38<14:30, 10.61s/it]
# Traceback (most recent call last):
#   File "/content/drive/My Drive/yolov5/train.py", line 848, in <module>
#     main(opt)
#   File "/content/drive/My Drive/yolov5/train.py", line 623, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/drive/My Drive/yolov5/train.py", line 390, in train
#     scaler.scale(loss).backward()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_tensor.py", line 522, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py", line 266, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %%
# Only run if training stops in between, training will resume from last epoch
# %cd /content/drive/My\ Drive
# %cd yolov5

# !python train.py --resume runs/train/exp15/weights/last.pt

# %% [markdown]
# ## Testing
# Following general steps taken here: https://www.kaggle.com/code/mostafaibrahim17/yolov5/notebook

# %%
# Directories for test dataset and weights for model
# Directories were updated to determine test and train accuracies for different iterations/datasets
test_dir = '../YOLOv5_work/images/train'
weights_dir = './runs/train/exp2/weights/best.pt'

# %%
# %cd /content/drive/My\ Drive
# !pip install ultralytics
# %cd yolov5
# !python detect.py --weights $weights_dir --img 352 --conf 0.4 --save-txt --source $test_dir
# Out:
# /content/drive/My Drive
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.1.42)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# /content/drive/My Drive/yolov5
# detect: weights=['./runs/train/exp2/weights/best.pt'], source=../YOLOv5_work/images/train, data=data/coco128.yaml, imgsz=[352, 352], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/My': No such file or directory
# YOLOv5 🚀 2024-4-2 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# image 1/4200 /content/drive/My Drive/YOLOv5_work/images/train/im0.jpg: 352x352 (no detections), 138.6ms
# image 2/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1000.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 131.0ms
# image 3/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10002.jpg: 352x352 (no detections), 118.7ms
# image 4/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10014.jpg: 352x352 (no detections), 131.7ms
# image 5/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10025.jpg: 352x352 1 short sleeve top, 124.6ms
# image 6/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10030.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 203.8ms
# image 7/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10031.jpg: 352x352 1 vest, 1 long sleeve outwear, 197.5ms
# image 8/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10047.jpg: 352x352 1 long sleeve outwear, 131.0ms
# image 9/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1005.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 120.4ms
# image 10/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10056.jpg: 352x352 1 short sleeve outwear, 130.9ms
# image 11/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10063.jpg: 352x352 1 vest dress, 123.5ms
# image 12/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1008.jpg: 352x352 1 vest dress, 1 sling dress, 122.9ms
# image 13/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10081.jpg: 352x352 1 vest dress, 121.9ms
# image 14/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10089.jpg: 352x352 (no detections), 142.6ms
# image 15/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10098.jpg: 352x352 1 short sleeve top, 1 long sleeve top, 122.5ms
# image 16/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1011.jpg: 352x352 1 short sleeve top, 146.8ms
# image 17/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10124.jpg: 352x352 (no detections), 134.7ms
# image 18/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10126.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 137.3ms
# image 19/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10139.jpg: 352x352 1 sling dress, 205.8ms
# image 20/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10167.jpg: 352x352 1 skirt, 1 short sleeve dress, 190.6ms
# image 21/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10171.jpg: 352x352 1 short sleeve top, 194.3ms
# image 22/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10174.jpg: 352x352 (no detections), 122.5ms
# image 23/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10176.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 134.4ms
# image 24/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10178.jpg: 352x352 1 sling dress, 145.5ms
# image 25/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10179.jpg: 352x352 1 short sleeve dress, 133.1ms
# image 26/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10180.jpg: 352x352 (no detections), 136.7ms
# image 27/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10196.jpg: 352x352 (no detections), 138.0ms
# image 28/4200 /content/drive/My Drive/YOLOv5_work/images/train/im102.jpg: 352x352 1 skirt, 1 short sleeve dress, 136.4ms
# image 29/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10205.jpg: 352x352 1 skirt, 1 vest dress, 121.1ms
# image 30/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10208.jpg: 352x352 1 short sleeve dress, 147.2ms
# image 31/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10212.jpg: 352x352 1 long sleeve top, 124.3ms
# image 32/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10214.jpg: 352x352 (no detections), 122.2ms
# image 33/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10223.jpg: 352x352 1 long sleeve top, 176.5ms
# image 34/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10225.jpg: 352x352 1 vest, 1 vest dress, 186.5ms
# image 35/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10227.jpg: 352x352 1 vest, 1 vest dress, 193.1ms
# image 36/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10236.jpg: 352x352 1 vest dress, 121.6ms
# image 37/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10237.jpg: 352x352 1 vest dress, 133.1ms
# image 38/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10258.jpg: 352x352 1 long sleeve outwear, 140.9ms
# image 39/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10264.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 138.8ms
# image 40/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10267.jpg: 352x352 1 short sleeve top, 132.7ms
# image 41/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10277.jpg: 352x352 (no detections), 127.3ms
# image 42/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10279.jpg: 352x352 1 vest, 1 vest dress, 126.6ms
# image 43/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10280.jpg: 352x352 1 short sleeve dress, 1 vest, 194.3ms
# image 44/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10291.jpg: 352x352 1 sling dress, 277.6ms
# image 45/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10306.jpg: 352x352 1 skirt, 1 long sleeve outwear, 232.9ms
# image 46/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10318.jpg: 352x352 (no detections), 199.0ms
# image 47/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10319.jpg: 352x352 1 sling dress, 164.5ms
# image 48/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10334.jpg: 352x352 1 short sleeve dress, 1 vest, 139.6ms
# image 49/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10337.jpg: 352x352 1 long sleeve top, 123.5ms
# image 50/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10347.jpg: 352x352 (no detections), 121.1ms
# image 51/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10350.jpg: 352x352 1 long sleeve top, 1 short sleeve outwear, 123.2ms
# image 52/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10356.jpg: 352x352 1 long sleeve outwear, 125.7ms
# image 53/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10357.jpg: 352x352 1 short sleeve dress, 1 vest, 1 long sleeve outwear, 122.1ms
# image 54/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10364.jpg: 352x352 1 skirt, 120.6ms
# image 55/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10367.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 134.0ms
# image 56/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10370.jpg: 352x352 1 vest dress, 1 sling dress, 126.4ms
# image 57/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10376.jpg: 352x352 (no detections), 129.4ms
# image 58/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10380.jpg: 352x352 1 vest, 1 vest dress, 130.2ms
# image 59/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10383.jpg: 352x352 (no detections), 123.5ms
# image 60/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10388.jpg: 352x352 1 skirt, 1 short sleeve dress, 122.9ms
# image 61/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10396.jpg: 352x352 1 vest dress, 135.8ms
# image 62/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1041.jpg: 352x352 1 long sleeve outwear, 126.6ms
# image 63/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10420.jpg: 352x352 1 skirt, 1 short sleeve dress, 138.2ms
# image 64/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10423.jpg: 352x352 (no detections), 120.9ms
# image 65/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10437.jpg: 352x352 (no detections), 121.9ms
# image 66/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10439.jpg: 352x352 1 long sleeve top, 126.6ms
# image 67/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10445.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 123.8ms
# image 68/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10451.jpg: 352x352 1 long sleeve top, 121.9ms
# image 69/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10457.jpg: 352x352 (no detections), 131.8ms
# image 70/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10459.jpg: 352x352 1 skirt, 132.4ms
# image 71/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10460.jpg: 352x352 1 skirt, 1 vest dress, 126.5ms
# image 72/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10463.jpg: 352x352 1 skirt, 1 vest dress, 131.1ms
# image 73/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10480.jpg: 352x352 1 long sleeve outwear, 138.2ms
# image 74/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10481.jpg: 352x352 1 skirt, 1 short sleeve dress, 123.3ms
# image 75/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10482.jpg: 352x352 (no detections), 122.5ms
# image 76/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10483.jpg: 352x352 (no detections), 123.7ms
# image 77/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10491.jpg: 352x352 1 vest, 1 vest dress, 121.7ms
# image 78/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10499.jpg: 352x352 1 skirt, 1 vest dress, 122.1ms
# image 79/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10511.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 126.2ms
# image 80/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10517.jpg: 352x352 1 short sleeve dress, 1 long sleeve outwear, 126.1ms
# image 81/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10524.jpg: 352x352 (no detections), 126.3ms
# image 82/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10528.jpg: 352x352 (no detections), 120.4ms
# image 83/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10535.jpg: 352x352 1 short sleeve dress, 121.7ms
# image 84/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10538.jpg: 352x352 1 long sleeve top, 121.8ms
# image 85/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10539.jpg: 352x352 1 sling dress, 1 long sleeve outwear, 123.1ms
# image 86/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10540.jpg: 352x352 1 vest dress, 137.0ms
# image 87/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10541.jpg: 352x352 1 skirt, 1 long sleeve outwear, 123.3ms
# image 88/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10543.jpg: 352x352 1 skirt, 1 vest dress, 124.1ms
# image 89/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10546.jpg: 352x352 1 short sleeve dress, 134.7ms
# image 90/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10549.jpg: 352x352 1 skirt, 1 vest dress, 125.7ms
# image 91/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10555.jpg: 352x352 1 long sleeve outwear, 120.5ms
# image 92/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10558.jpg: 352x352 1 vest dress, 1 sling dress, 122.8ms
# image 93/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10564.jpg: 352x352 1 short sleeve top, 121.9ms
# image 94/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10575.jpg: 352x352 1 vest, 1 vest dress, 147.5ms
# image 95/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10587.jpg: 352x352 1 vest dress, 124.1ms
# image 96/4200 /content/drive/My Drive/YOLOv5_work/images/train/im106.jpg: 352x352 1 short sleeve dress, 128.8ms
# image 97/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10610.jpg: 352x352 1 skirt, 121.8ms
# image 98/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10636.jpg: 352x352 1 long sleeve outwear, 124.7ms
# image 99/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10637.jpg: 352x352 (no detections), 136.1ms
# image 100/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10645.jpg: 352x352 1 long sleeve top, 129.0ms
# image 101/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10647.jpg: 352x352 (no detections), 123.0ms
# image 102/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10650.jpg: 352x352 (no detections), 120.7ms
# image 103/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10659.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 122.5ms
# image 104/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1066.jpg: 352x352 1 vest dress, 1 sling dress, 121.3ms
# image 105/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10660.jpg: 352x352 (no detections), 157.3ms
# image 106/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10661.jpg: 352x352 1 short sleeve outwear, 2 long sleeve outwears, 122.1ms
# image 107/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10664.jpg: 352x352 1 skirt, 1 vest, 1 long sleeve outwear, 122.6ms
# image 108/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10670.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 118.5ms
# image 109/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1068.jpg: 352x352 (no detections), 194.9ms
# image 110/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10696.jpg: 352x352 1 skirt, 1 long sleeve outwear, 197.4ms
# image 111/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10708.jpg: 352x352 1 vest dress, 1 sling dress, 213.1ms
# image 112/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10727.jpg: 352x352 1 vest, 1 vest dress, 192.7ms
# image 113/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10731.jpg: 352x352 (no detections), 194.6ms
# image 114/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10738.jpg: 352x352 1 short sleeve top, 204.1ms
# image 115/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10739.jpg: 352x352 (no detections), 202.7ms
# image 116/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10750.jpg: 352x352 1 sling dress, 197.4ms
# image 117/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10756.jpg: 352x352 (no detections), 190.8ms
# image 118/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10759.jpg: 352x352 1 sling dress, 192.7ms
# image 119/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10761.jpg: 352x352 (no detections), 264.1ms
# image 120/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10763.jpg: 352x352 (no detections), 208.9ms
# image 121/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10776.jpg: 352x352 1 short sleeve outwear, 190.9ms
# image 122/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10793.jpg: 352x352 1 skirt, 1 short sleeve dress, 191.9ms
# image 123/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1081.jpg: 352x352 1 long sleeve top, 197.5ms
# image 124/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10820.jpg: 352x352 1 sling dress, 1 long sleeve outwear, 208.9ms
# image 125/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10821.jpg: 352x352 1 short sleeve top, 198.0ms
# image 126/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10830.jpg: 352x352 1 short sleeve top, 192.5ms
# image 127/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10831.jpg: 352x352 (no detections), 201.0ms
# image 128/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10833.jpg: 352x352 1 long sleeve top, 196.4ms
# image 129/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10835.jpg: 352x352 1 short sleeve dress, 1 vest, 205.3ms
# image 130/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10848.jpg: 352x352 1 vest, 1 long sleeve outwear, 188.2ms
# image 131/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10854.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 214.8ms
# image 132/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10862.jpg: 352x352 2 vests, 2 vest dresss, 198.7ms
# image 133/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10865.jpg: 352x352 (no detections), 206.4ms
# image 134/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10875.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 194.7ms
# image 135/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10887.jpg: 352x352 1 vest, 1 vest dress, 200.9ms
# image 136/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10893.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 198.4ms
# image 137/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10902.jpg: 352x352 1 short sleeve dress, 1 vest, 211.6ms
# image 138/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10906.jpg: 352x352 1 short sleeve top, 1 long sleeve top, 161.7ms
# image 139/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10916.jpg: 352x352 1 long sleeve outwear, 122.8ms
# image 140/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10920.jpg: 352x352 1 sling dress, 123.7ms
# image 141/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10921.jpg: 352x352 1 short sleeve dress, 133.2ms
# image 142/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10934.jpg: 352x352 1 vest, 1 vest dress, 119.9ms
# image 143/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10935.jpg: 352x352 (no detections), 136.0ms
# image 144/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10939.jpg: 352x352 (no detections), 130.8ms
# image 145/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10946.jpg: 352x352 1 vest, 1 vest dress, 121.1ms
# image 146/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10947.jpg: 352x352 (no detections), 127.3ms
# image 147/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10949.jpg: 352x352 1 short sleeve dress, 139.4ms
# image 148/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10954.jpg: 352x352 1 vest dress, 122.9ms
# image 149/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10957.jpg: 352x352 (no detections), 128.6ms
# image 150/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10966.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 136.8ms
# image 151/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1097.jpg: 352x352 1 sling dress, 125.7ms
# image 152/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10995.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 129.3ms
# image 153/4200 /content/drive/My Drive/YOLOv5_work/images/train/im10997.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 127.2ms
# image 154/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11000.jpg: 352x352 1 sling dress, 121.4ms
# image 155/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11012.jpg: 352x352 1 long sleeve top, 121.2ms
# image 156/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11013.jpg: 352x352 1 vest dress, 135.1ms
# image 157/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11021.jpg: 352x352 1 vest, 1 vest dress, 122.2ms
# image 158/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11022.jpg: 352x352 2 vest dresss, 128.6ms
# image 159/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11023.jpg: 352x352 1 vest, 124.2ms
# image 160/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11024.jpg: 352x352 1 skirt, 1 short sleeve dress, 127.1ms
# image 161/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11043.jpg: 352x352 1 short sleeve outwear, 2 long sleeve outwears, 124.6ms
# image 162/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11054.jpg: 352x352 1 vest dress, 138.3ms
# image 163/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11061.jpg: 352x352 (no detections), 131.7ms
# image 164/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11068.jpg: 352x352 1 vest, 150.6ms
# image 165/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11072.jpg: 352x352 1 sling dress, 121.5ms
# image 166/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1109.jpg: 352x352 1 short sleeve top, 1 long sleeve top, 128.0ms
# image 167/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11110.jpg: 352x352 (no detections), 124.4ms
# image 168/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11116.jpg: 352x352 1 short sleeve top, 118.2ms
# image 169/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11119.jpg: 352x352 (no detections), 127.3ms
# image 170/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11121.jpg: 352x352 (no detections), 116.7ms
# image 171/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11125.jpg: 352x352 1 short sleeve top, 1 long sleeve top, 121.6ms
# image 172/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11128.jpg: 352x352 1 long sleeve outwear, 123.0ms
# image 173/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11129.jpg: 352x352 1 skirt, 117.8ms
# image 174/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11130.jpg: 352x352 1 vest, 1 vest dress, 123.2ms
# image 175/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11152.jpg: 352x352 1 vest dress, 1 sling dress, 131.5ms
# image 176/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11158.jpg: 352x352 (no detections), 122.2ms
# image 177/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11163.jpg: 352x352 (no detections), 127.6ms
# image 178/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11165.jpg: 352x352 (no detections), 127.5ms
# image 179/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1118.jpg: 352x352 1 skirt, 1 short sleeve dress, 121.3ms
# image 180/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11180.jpg: 352x352 1 sling dress, 124.9ms
# image 181/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11184.jpg: 352x352 1 sling dress, 125.8ms
# image 182/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11192.jpg: 352x352 (no detections), 139.6ms
# image 183/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11195.jpg: 352x352 1 skirt, 1 vest dress, 124.8ms
# image 184/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11203.jpg: 352x352 2 long sleeve outwears, 132.3ms
# image 185/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11220.jpg: 352x352 1 long sleeve top, 122.8ms
# image 186/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11222.jpg: 352x352 1 short sleeve dress, 1 vest, 116.6ms
# image 187/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11237.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 127.8ms
# image 188/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11248.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 138.1ms
# image 189/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11250.jpg: 352x352 (no detections), 122.5ms
# image 190/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11263.jpg: 352x352 (no detections), 124.3ms
# image 191/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11264.jpg: 352x352 (no detections), 124.3ms
# image 192/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11272.jpg: 352x352 1 vest dress, 127.7ms
# image 193/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11276.jpg: 352x352 1 short sleeve top, 126.1ms
# image 194/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11278.jpg: 352x352 1 vest dress, 120.7ms
# image 195/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11279.jpg: 352x352 1 vest dress, 1 sling dress, 141.0ms
# image 196/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11281.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 136.9ms
# image 197/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11285.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 124.7ms
# image 198/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11293.jpg: 352x352 (no detections), 124.3ms
# image 199/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11295.jpg: 352x352 1 vest dress, 140.2ms
# image 200/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11299.jpg: 352x352 1 skirt, 1 short sleeve dress, 124.5ms
# image 201/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11303.jpg: 352x352 1 skirt, 1 short sleeve dress, 209.9ms
# image 202/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11320.jpg: 352x352 (no detections), 198.6ms
# image 203/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11327.jpg: 352x352 1 short sleeve top, 200.5ms
# image 204/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11356.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 195.0ms
# image 205/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11360.jpg: 352x352 1 vest dress, 247.3ms
# image 206/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11378.jpg: 352x352 1 short sleeve dress, 191.7ms
# image 207/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1138.jpg: 352x352 1 vest dress, 197.2ms
# image 208/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11381.jpg: 352x352 (no detections), 190.7ms
# image 209/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11385.jpg: 352x352 1 short sleeve top, 191.3ms
# image 210/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11390.jpg: 352x352 1 skirt, 1 vest dress, 209.8ms
# image 211/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11396.jpg: 352x352 1 skirt, 1 long sleeve outwear, 203.6ms
# image 212/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11420.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 1 long sleeve outwear, 193.3ms
# image 213/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11422.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 200.4ms
# image 214/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11431.jpg: 352x352 1 vest, 1 vest dress, 202.5ms
# image 215/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11444.jpg: 352x352 1 vest dress, 1 sling dress, 198.2ms
# image 216/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11449.jpg: 352x352 1 vest dress, 1 sling dress, 228.8ms
# image 217/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1147.jpg: 352x352 1 short sleeve top, 188.5ms
# image 218/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1148.jpg: 352x352 2 long sleeve outwears, 206.0ms
# image 219/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11494.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 217.1ms
# image 220/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11501.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 191.9ms
# image 221/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11505.jpg: 352x352 (no detections), 187.1ms
# image 222/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11510.jpg: 352x352 1 long sleeve outwear, 207.5ms
# image 223/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11522.jpg: 352x352 (no detections), 216.2ms
# image 224/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11529.jpg: 352x352 (no detections), 188.8ms
# image 225/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11536.jpg: 352x352 1 short sleeve dress, 192.7ms
# image 226/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11540.jpg: 352x352 1 skirt, 1 vest dress, 195.0ms
# image 227/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11544.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 209.2ms
# image 228/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11555.jpg: 352x352 (no detections), 196.7ms
# image 229/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11561.jpg: 352x352 (no detections), 195.8ms
# image 230/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11566.jpg: 352x352 (no detections), 162.3ms
# image 231/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11571.jpg: 352x352 1 sling dress, 133.6ms
# image 232/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11573.jpg: 352x352 1 vest dress, 127.1ms
# image 233/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11581.jpg: 352x352 1 short sleeve top, 151.0ms
# image 234/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11583.jpg: 352x352 1 sling dress, 1 long sleeve outwear, 139.0ms
# image 235/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11593.jpg: 352x352 1 long sleeve outwear, 138.3ms
# image 236/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11595.jpg: 352x352 1 vest dress, 131.4ms
# image 237/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11609.jpg: 352x352 (no detections), 146.9ms
# image 238/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1161.jpg: 352x352 1 sling dress, 136.6ms
# image 239/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11622.jpg: 352x352 1 skirt, 1 vest dress, 143.8ms
# image 240/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11629.jpg: 352x352 (no detections), 139.5ms
# image 241/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11631.jpg: 352x352 1 short sleeve top, 142.7ms
# image 242/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11644.jpg: 352x352 (no detections), 144.5ms
# image 243/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1167.jpg: 352x352 1 vest dress, 140.3ms
# image 244/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11678.jpg: 352x352 1 long sleeve top, 162.8ms
# image 245/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11680.jpg: 352x352 1 long sleeve top, 143.2ms
# image 246/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1169.jpg: 352x352 (no detections), 143.9ms
# image 247/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1170.jpg: 352x352 1 vest, 1 vest dress, 161.8ms
# image 248/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11701.jpg: 352x352 (no detections), 147.4ms
# image 249/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11706.jpg: 352x352 1 vest, 1 vest dress, 146.2ms
# image 250/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11709.jpg: 352x352 (no detections), 155.6ms
# image 251/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11710.jpg: 352x352 (no detections), 141.4ms
# image 252/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11718.jpg: 352x352 1 vest, 1 vest dress, 143.7ms
# image 253/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11730.jpg: 352x352 (no detections), 131.8ms
# image 254/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11734.jpg: 352x352 1 sling dress, 141.7ms
# image 255/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11738.jpg: 352x352 1 sling dress, 1 long sleeve outwear, 135.2ms
# image 256/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11739.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 153.5ms
# image 257/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11743.jpg: 352x352 1 vest dress, 1 sling dress, 137.9ms
# image 258/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11762.jpg: 352x352 1 short sleeve dress, 135.4ms
# image 259/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11763.jpg: 352x352 1 sling dress, 138.5ms
# image 260/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11766.jpg: 352x352 1 vest, 1 vest dress, 158.5ms
# image 261/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11775.jpg: 352x352 1 vest, 1 vest dress, 142.5ms
# image 262/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11782.jpg: 352x352 1 vest dress, 139.9ms
# image 263/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11789.jpg: 352x352 1 sling dress, 133.5ms
# image 264/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11795.jpg: 352x352 1 skirt, 1 short sleeve dress, 140.8ms
# image 265/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11804.jpg: 352x352 1 vest dress, 1 sling dress, 132.8ms
# image 266/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11805.jpg: 352x352 1 long sleeve top, 131.6ms
# image 267/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11818.jpg: 352x352 (no detections), 146.7ms
# image 268/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11825.jpg: 352x352 1 long sleeve top, 129.7ms
# image 269/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11830.jpg: 352x352 1 short sleeve top, 1 long sleeve top, 1 vest, 135.7ms
# image 270/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11836.jpg: 352x352 1 vest dress, 1 sling dress, 143.5ms
# image 271/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11837.jpg: 352x352 1 short sleeve dress, 144.6ms
# image 272/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11845.jpg: 352x352 1 vest, 1 vest dress, 133.1ms
# image 273/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11849.jpg: 352x352 1 short sleeve top, 144.9ms
# image 274/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11855.jpg: 352x352 (no detections), 130.2ms
# image 275/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11860.jpg: 352x352 1 short sleeve dress, 150.0ms
# image 276/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11906.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 139.2ms
# image 277/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11913.jpg: 352x352 1 vest dress, 145.4ms
# image 278/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11921.jpg: 352x352 (no detections), 144.6ms
# image 279/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11926.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 152.7ms
# image 280/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11927.jpg: 352x352 1 short sleeve top, 131.9ms
# image 281/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11940.jpg: 352x352 (no detections), 132.5ms
# image 282/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11942.jpg: 352x352 1 vest dress, 1 sling dress, 132.7ms
# image 283/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11948.jpg: 352x352 1 short sleeve dress, 137.3ms
# image 284/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11956.jpg: 352x352 1 vest dress, 1 sling dress, 139.0ms
# image 285/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11959.jpg: 352x352 (no detections), 145.1ms
# image 286/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11970.jpg: 352x352 (no detections), 164.7ms
# image 287/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11971.jpg: 352x352 1 vest, 1 long sleeve outwear, 232.8ms
# image 288/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11974.jpg: 352x352 1 vest dress, 1 sling dress, 204.8ms
# image 289/4200 /content/drive/My Drive/YOLOv5_work/images/train/im11980.jpg: 352x352 (no detections), 221.4ms
# image 290/4200 /content/drive/My Drive/YOLOv5_work/images/train/im120.jpg: 352x352 (no detections), 205.9ms
# image 291/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12013.jpg: 352x352 1 short sleeve outwear, 219.7ms
# image 292/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12016.jpg: 352x352 1 long sleeve top, 232.0ms
# image 293/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12023.jpg: 352x352 1 vest, 1 vest dress, 216.0ms
# image 294/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12024.jpg: 352x352 (no detections), 245.3ms
# image 295/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1203.jpg: 352x352 1 vest dress, 218.0ms
# image 296/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12037.jpg: 352x352 (no detections), 205.1ms
# image 297/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12046.jpg: 352x352 1 sling dress, 218.8ms
# image 298/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1206.jpg: 352x352 (no detections), 210.2ms
# image 299/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12069.jpg: 352x352 (no detections), 253.3ms
# image 300/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12075.jpg: 352x352 2 vest dresss, 1 sling dress, 211.2ms
# image 301/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12078.jpg: 352x352 1 long sleeve top, 203.5ms
# image 302/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12079.jpg: 352x352 1 skirt, 1 short sleeve dress, 267.2ms
# image 303/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12083.jpg: 352x352 1 vest dress, 210.2ms
# image 304/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12084.jpg: 352x352 1 vest dress, 1 sling dress, 229.1ms
# image 305/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12089.jpg: 352x352 1 vest dress, 219.5ms
# image 306/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12092.jpg: 352x352 1 skirt, 219.4ms
# image 307/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12100.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 207.0ms
# image 308/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12103.jpg: 352x352 1 vest, 1 vest dress, 216.5ms
# image 309/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12104.jpg: 352x352 1 skirt, 216.5ms
# image 310/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12116.jpg: 352x352 1 vest dress, 226.9ms
# image 311/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1212.jpg: 352x352 1 vest dress, 1 sling dress, 210.3ms
# image 312/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1213.jpg: 352x352 1 vest, 1 vest dress, 212.4ms
# image 313/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12134.jpg: 352x352 1 skirt, 210.8ms
# image 314/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12136.jpg: 352x352 1 sling dress, 216.1ms
# image 315/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12137.jpg: 352x352 (no detections), 192.3ms
# image 316/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12139.jpg: 352x352 1 sling dress, 133.3ms
# image 317/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12141.jpg: 352x352 1 vest dress, 1 sling dress, 132.4ms
# image 318/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12161.jpg: 352x352 (no detections), 135.3ms
# image 319/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12168.jpg: 352x352 1 vest, 1 vest dress, 130.1ms
# image 320/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12171.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 136.3ms
# image 321/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12182.jpg: 352x352 1 short sleeve outwear, 135.3ms
# image 322/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12188.jpg: 352x352 1 vest dress, 1 sling dress, 133.6ms
# image 323/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12208.jpg: 352x352 1 vest dress, 130.6ms
# image 324/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12212.jpg: 352x352 1 long sleeve top, 133.2ms
# image 325/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12219.jpg: 352x352 1 vest dress, 1 sling dress, 133.5ms
# image 326/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1222.jpg: 352x352 (no detections), 139.1ms
# image 327/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12220.jpg: 352x352 1 vest dress, 136.1ms
# image 328/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12234.jpg: 352x352 (no detections), 134.5ms
# image 329/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1224.jpg: 352x352 1 vest, 134.7ms
# image 330/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12251.jpg: 352x352 1 short sleeve top, 1 long sleeve outwear, 140.4ms
# image 331/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12254.jpg: 352x352 (no detections), 139.6ms
# image 332/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12259.jpg: 352x352 1 short sleeve dress, 130.2ms
# image 333/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12266.jpg: 352x352 (no detections), 133.2ms
# image 334/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12269.jpg: 352x352 (no detections), 134.2ms
# image 335/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12271.jpg: 352x352 1 short sleeve top, 133.9ms
# image 336/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12274.jpg: 352x352 1 long sleeve outwear, 139.8ms
# image 337/4200 /content/drive/My Drive/YOLOv5_work/images/train/im1228.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 148.2ms
# image 338/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12280.jpg: 352x352 1 skirt, 1 short sleeve dress, 143.6ms
# image 339/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12284.jpg: 352x352 1 short sleeve outwear, 136.8ms
# image 340/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12286.jpg: 352x352 (no detections), 140.1ms
# image 341/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12305.jpg: 352x352 1 skirt, 1 short sleeve dress, 1 vest dress, 146.9ms
# image 342/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12311.jpg: 352x352 1 skirt, 1 short sleeve dress, 160.8ms
# image 343/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12317.jpg: 352x352 (no detections), 131.6ms
# image 344/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12319.jpg: 352x352 1 short sleeve top, 145.9ms
# image 345/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12323.jpg: 352x352 1 short sleeve top, 1 vest dress, 139.2ms
# image 346/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12335.jpg: 352x352 (no detections), 144.7ms
# image 347/4200 /content/drive/My Drive/YOLOv5_work/images/train/im12341.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 140.8ms
# ...
# image 4066/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9092.jpg: 352x352 (no detections), 133.7ms
# image 4067/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9093.jpg: 352x352 1 vest, 1 long sleeve outwear, 115.9ms
# image 4068/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9107.jpg: 352x352 1 vest dress, 1 sling dress, 120.8ms
# image 4069/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9109.jpg: 352x352 1 vest dress, 1 sling dress, 119.0ms
# image 4070/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9110.jpg: 352x352 1 vest dress, 129.0ms
# image 4071/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9119.jpg: 352x352 (no detections), 122.1ms
# image 4072/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9120.jpg: 352x352 1 skirt, 1 short sleeve dress, 136.9ms
# image 4073/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9123.jpg: 352x352 1 long sleeve top, 123.9ms
# image 4074/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9127.jpg: 352x352 (no detections), 126.0ms
# image 4075/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9139.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 118.1ms
# image 4076/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9140.jpg: 352x352 1 sling dress, 143.0ms
# image 4077/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9144.jpg: 352x352 1 skirt, 1 short sleeve dress, 1 vest, 119.0ms
# image 4078/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9148.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 133.0ms
# image 4079/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9154.jpg: 352x352 1 vest, 1 long sleeve outwear, 128.6ms
# image 4080/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9155.jpg: 352x352 1 short sleeve dress, 1 short sleeve outwear, 136.1ms
# image 4081/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9167.jpg: 352x352 1 sling dress, 119.5ms
# image 4082/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9169.jpg: 352x352 1 short sleeve dress, 140.1ms
# image 4083/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9205.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 118.1ms
# image 4084/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9210.jpg: 352x352 (no detections), 127.8ms
# image 4085/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9218.jpg: 352x352 1 vest dress, 125.4ms
# image 4086/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9226.jpg: 352x352 1 short sleeve outwear, 122.1ms
# image 4087/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9231.jpg: 352x352 1 vest dress, 119.2ms
# image 4088/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9233.jpg: 352x352 (no detections), 121.6ms
# image 4089/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9240.jpg: 352x352 (no detections), 138.7ms
# image 4090/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9243.jpg: 352x352 1 vest dress, 1 sling dress, 121.8ms
# image 4091/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9244.jpg: 352x352 1 short sleeve dress, 130.4ms
# image 4092/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9246.jpg: 352x352 1 vest dress, 120.7ms
# image 4093/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9296.jpg: 352x352 1 vest dress, 1 sling dress, 127.7ms
# image 4094/4200 /content/drive/My Drive/YOLOv5_work/images/train/im93.jpg: 352x352 (no detections), 122.3ms
# image 4095/4200 /content/drive/My Drive/YOLOv5_work/images/train/im930.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 129.2ms
# image 4096/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9305.jpg: 352x352 (no detections), 119.9ms
# image 4097/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9308.jpg: 352x352 1 vest dress, 120.7ms
# image 4098/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9316.jpg: 352x352 (no detections), 121.7ms
# image 4099/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9319.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 122.8ms
# image 4100/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9325.jpg: 352x352 1 skirt, 1 short sleeve dress, 121.0ms
# image 4101/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9327.jpg: 352x352 1 vest dress, 121.5ms
# image 4102/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9340.jpg: 352x352 1 skirt, 1 vest, 127.5ms
# image 4103/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9341.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 129.4ms
# image 4104/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9343.jpg: 352x352 1 skirt, 1 vest dress, 119.4ms
# image 4105/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9344.jpg: 352x352 1 skirt, 1 short sleeve dress, 1 vest dress, 127.9ms
# image 4106/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9348.jpg: 352x352 (no detections), 128.3ms
# image 4107/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9352.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 128.3ms
# image 4108/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9358.jpg: 352x352 1 vest dress, 1 sling dress, 120.1ms
# image 4109/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9400.jpg: 352x352 1 skirt, 1 long sleeve outwear, 130.0ms
# image 4110/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9411.jpg: 352x352 1 sling dress, 197.9ms
# image 4111/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9431.jpg: 352x352 (no detections), 213.9ms
# image 4112/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9435.jpg: 352x352 (no detections), 186.3ms
# image 4113/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9445.jpg: 352x352 1 skirt, 1 short sleeve dress, 240.1ms
# image 4114/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9452.jpg: 352x352 1 vest, 1 vest dress, 202.3ms
# image 4115/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9461.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 203.6ms
# image 4116/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9463.jpg: 352x352 (no detections), 194.9ms
# image 4117/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9467.jpg: 352x352 1 vest, 1 vest dress, 193.1ms
# image 4118/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9469.jpg: 352x352 1 vest dress, 214.1ms
# image 4119/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9473.jpg: 352x352 (no detections), 199.7ms
# image 4120/4200 /content/drive/My Drive/YOLOv5_work/images/train/im948.jpg: 352x352 (no detections), 192.5ms
# image 4121/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9489.jpg: 352x352 1 skirt, 197.5ms
# image 4122/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9491.jpg: 352x352 1 skirt, 1 vest dress, 202.0ms
# image 4123/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9496.jpg: 352x352 1 vest dress, 187.9ms
# image 4124/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9498.jpg: 352x352 1 sling dress, 193.8ms
# image 4125/4200 /content/drive/My Drive/YOLOv5_work/images/train/im95.jpg: 352x352 1 short sleeve top, 1 long sleeve outwear, 182.7ms
# image 4126/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9503.jpg: 352x352 1 vest, 1 vest dress, 188.7ms
# image 4127/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9507.jpg: 352x352 1 short sleeve outwear, 129.6ms
# image 4128/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9511.jpg: 352x352 1 long sleeve outwear, 132.2ms
# image 4129/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9514.jpg: 352x352 1 vest, 125.0ms
# image 4130/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9532.jpg: 352x352 1 vest dress, 125.2ms
# image 4131/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9534.jpg: 352x352 (no detections), 119.5ms
# image 4132/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9541.jpg: 352x352 1 short sleeve top, 126.8ms
# image 4133/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9551.jpg: 352x352 1 skirt, 1 short sleeve dress, 130.1ms
# image 4134/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9556.jpg: 352x352 (no detections), 132.3ms
# image 4135/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9562.jpg: 352x352 1 short sleeve top, 122.6ms
# image 4136/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9565.jpg: 352x352 1 vest dress, 120.8ms
# image 4137/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9567.jpg: 352x352 1 vest, 1 vest dress, 121.7ms
# image 4138/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9568.jpg: 352x352 1 vest dress, 132.5ms
# image 4139/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9571.jpg: 352x352 1 skirt, 1 vest dress, 139.9ms
# image 4140/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9577.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 152.4ms
# image 4141/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9582.jpg: 352x352 1 vest, 122.2ms
# image 4142/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9586.jpg: 352x352 1 skirt, 1 vest dress, 125.6ms
# image 4143/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9588.jpg: 352x352 1 skirt, 1 vest dress, 122.0ms
# image 4144/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9593.jpg: 352x352 1 long sleeve top, 121.0ms
# image 4145/4200 /content/drive/My Drive/YOLOv5_work/images/train/im96.jpg: 352x352 1 short sleeve dress, 1 vest, 121.3ms
# image 4146/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9612.jpg: 352x352 1 short sleeve dress, 141.2ms
# image 4147/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9614.jpg: 352x352 (no detections), 128.6ms
# image 4148/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9628.jpg: 352x352 1 short sleeve dress, 1 vest, 129.1ms
# image 4149/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9642.jpg: 352x352 1 skirt, 1 short sleeve dress, 119.4ms
# image 4150/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9643.jpg: 352x352 1 vest dress, 1 short sleeve outwear, 134.8ms
# image 4151/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9647.jpg: 352x352 1 short sleeve top, 128.1ms
# image 4152/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9648.jpg: 352x352 (no detections), 130.9ms
# image 4153/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9649.jpg: 352x352 1 vest, 126.5ms
# image 4154/4200 /content/drive/My Drive/YOLOv5_work/images/train/im965.jpg: 352x352 1 vest, 1 vest dress, 126.7ms
# image 4155/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9656.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 122.6ms
# image 4156/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9661.jpg: 352x352 1 sling dress, 137.1ms
# image 4157/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9665.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 125.7ms
# image 4158/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9676.jpg: 352x352 2 vest dresss, 125.8ms
# image 4159/4200 /content/drive/My Drive/YOLOv5_work/images/train/im969.jpg: 352x352 1 long sleeve top, 119.8ms
# image 4160/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9699.jpg: 352x352 1 sling dress, 116.9ms
# image 4161/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9704.jpg: 352x352 1 vest, 1 long sleeve outwear, 126.8ms
# image 4162/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9721.jpg: 352x352 1 vest dress, 122.7ms
# image 4163/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9722.jpg: 352x352 (no detections), 121.8ms
# image 4164/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9723.jpg: 352x352 1 vest dress, 126.7ms
# image 4165/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9732.jpg: 352x352 1 long sleeve top, 134.8ms
# image 4166/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9737.jpg: 352x352 1 skirt, 1 vest, 1 vest dress, 130.7ms
# image 4167/4200 /content/drive/My Drive/YOLOv5_work/images/train/im974.jpg: 352x352 (no detections), 123.2ms
# image 4168/4200 /content/drive/My Drive/YOLOv5_work/images/train/im975.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 129.6ms
# image 4169/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9757.jpg: 352x352 1 sling dress, 131.6ms
# image 4170/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9768.jpg: 352x352 (no detections), 122.8ms
# image 4171/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9769.jpg: 352x352 1 short sleeve top, 1 long sleeve outwear, 129.5ms
# image 4172/4200 /content/drive/My Drive/YOLOv5_work/images/train/im977.jpg: 352x352 (no detections), 127.1ms
# image 4173/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9770.jpg: 352x352 1 skirt, 1 vest dress, 129.0ms
# image 4174/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9780.jpg: 352x352 (no detections), 125.3ms
# image 4175/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9785.jpg: 352x352 (no detections), 131.4ms
# image 4176/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9787.jpg: 352x352 1 short sleeve outwear, 1 long sleeve outwear, 124.5ms
# image 4177/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9792.jpg: 352x352 1 short sleeve dress, 137.5ms
# image 4178/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9798.jpg: 352x352 1 vest, 1 vest dress, 130.8ms
# image 4179/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9808.jpg: 352x352 1 vest dress, 1 long sleeve outwear, 140.2ms
# image 4180/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9817.jpg: 352x352 1 vest dress, 1 sling dress, 122.8ms
# image 4181/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9827.jpg: 352x352 1 skirt, 156.0ms
# image 4182/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9834.jpg: 352x352 1 vest, 127.5ms
# image 4183/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9864.jpg: 352x352 1 long sleeve top, 134.5ms
# image 4184/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9866.jpg: 352x352 (no detections), 133.8ms
# image 4185/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9882.jpg: 352x352 1 vest dress, 124.4ms
# image 4186/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9886.jpg: 352x352 1 sling dress, 123.2ms
# image 4187/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9894.jpg: 352x352 (no detections), 127.6ms
# image 4188/4200 /content/drive/My Drive/YOLOv5_work/images/train/im99.jpg: 352x352 1 sling dress, 202.6ms
# image 4189/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9911.jpg: 352x352 (no detections), 201.8ms
# image 4190/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9912.jpg: 352x352 1 vest dress, 231.8ms
# image 4191/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9919.jpg: 352x352 1 long sleeve top, 1 short sleeve outwear, 191.2ms
# image 4192/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9929.jpg: 352x352 1 vest dress, 1 sling dress, 192.7ms
# image 4193/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9936.jpg: 352x352 1 skirt, 1 long sleeve outwear, 195.2ms
# image 4194/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9944.jpg: 352x352 1 long sleeve outwear, 224.9ms
# image 4195/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9946.jpg: 352x352 1 sling dress, 217.3ms
# image 4196/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9965.jpg: 352x352 1 vest dress, 1 sling dress, 194.9ms
# image 4197/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9973.jpg: 352x352 1 skirt, 1 vest dress, 189.4ms
# image 4198/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9979.jpg: 352x352 1 skirt, 1 short sleeve dress, 206.2ms
# image 4199/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9990.jpg: 352x352 (no detections), 236.8ms
# image 4200/4200 /content/drive/My Drive/YOLOv5_work/images/train/im9991.jpg: 352x352 1 skirt, 1 short sleeve dress, 194.9ms
# Speed: 0.6ms pre-process, 143.5ms inference, 0.8ms NMS per image at shape (1, 3, 352, 352)
# Results saved to runs/detect/exp8
# 3318 labels saved to runs/detect/exp8/labels

# %%
def yolo2voc(image_height, image_width, bboxes):
    """
    Convert YOLO bbox to voc format to determine IoU
    yolo => [xmid, ymid, w, h] (normalized)
    voc  => [x1, y1, x2, y1]
    """

    bboxes[0], bboxes[2] = bboxes[0]*image_width, bboxes[2]*image_width
    bboxes[1], bboxes[3] = bboxes[1]*image_height, bboxes[3]*image_height

    bboxes[0] = bboxes[0] - bboxes[2]/2
    bboxes[1] = bboxes[1] - bboxes[3]/2
    bboxes[2] = bboxes[0] + bboxes[2]
    bboxes[3] = bboxes[1] + bboxes[3]

    return bboxes

# %%
def get_iou(bb1, bb2):
    """
    Determines IoU between 2 bounding boxes
    Derived from: https://github.com/1297rohit/RCNN/blob/master/RCNN.ipynb
    """

    x_left = max(bb1[0], bb2[0])
    y_top = max(bb1[1], bb2[1])
    x_right = min(bb1[2], bb2[2])
    y_bottom = min(bb1[3], bb2[3])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1[2] - bb1[0]) * (bb1[3] - bb1[1])
    bb2_area = (bb2[2] - bb2[0]) * (bb2[3] - bb2[1])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)

    assert iou >= 0.0
    assert iou <= 1.0

    return iou

# %%
from glob import glob

# Directories were updated to determine test and train accuracies for different iterations/datasets
test_labels_dir = '/content/drive/My Drive/YOLOv5_work/labels/train'
pred_labels_dir = '/content/drive/My Drive/yolov5/runs/detect/exp8/labels/*txt'

def get_accuracy_and_iou(test_labels_dir, pred_labels_dir):
  """
  Goes through test dataset (ground truth) and predictions to determine classification accuracy and average IoU
  """

  # Initialize counters + iou
  correct_predict = 0
  total_predict = 0
  iou = 0

  # Iterate through each data point that had a prediction
  for file_path in tqdm(glob(pred_labels_dir)):
      image_id = file_path.split('/')[-1].split('.')[0] # Extract image id
      ground_truth_path = os.path.join(test_labels_dir, image_id + '.txt')

      # Get predicted classes and bbox for current data point
      pred_class = []
      pred_bbox = []

      f = open(file_path, 'r')
      for line in f:
        values = line.strip().split()
        pred_class.append(values[0])
        bbox = yolo2voc(352, 352, [float(j) for j in values[1:]])
        pred_bbox.append(bbox)

      # Get predicted classes and bbox for current data point
      true_class = []
      true_bbox = []

      f = open(ground_truth_path, 'r')
      for line in f:
        values = line.strip().split()
        true_class.append(values[0])
        bbox = yolo2voc(352, 352, [float(j) for j in values[1:]])
        true_bbox.append(bbox)

      # Determine if there was a correct prediction(s) and the corresponding IoU
      for i in range(len(true_class)):
        if true_class[i] in pred_class:
          correct_predict+=1
          iou += get_iou(true_bbox[i], pred_bbox[pred_class.index(true_class[i])])

      for i in pred_class:
        total_predict+=1

  accuracy = correct_predict/total_predict
  avg_iou = iou/correct_predict

  return accuracy, avg_iou

print(get_accuracy_and_iou(test_labels_dir, pred_labels_dir))
# Out:
# 100%|██████████| 3318/3318 [27:36<00:00,  2.00it/s]
# (0.7922548645555132, 0.8661244699856329)
